# %% [markdown]
# # RADx-rad Publication Relevance Classification Using Likert Scores and LLMs
#
# This notebook classifies scientific publications for relevance to RADx-rad program objectives using Large Language Models (LLMs).
#
# Publications referencing RADx-rad grant numbers are evaluated to determine how closely they align with:
#
# - **Funding Opportunity Announcements (FOAs)** objectives (based on full-text descriptions)
# - **dbGaP Study Objectives** (based on study titles and abstracts)
#
# LLMs assess relevance by comparing each publication's title and abstract against FOA descriptions and dbGaP study details, assigning a relevance score on a 5-point [Likert scale](https://www.scribbr.com/methodology/likert-scale/). Each LLM evaluation also includes a rationale explaining the assigned score.
#
#
# ## Workflow Overview
#
# 1. **Data Integration**
#    - Load and merge preprocessed FOA, dbGaP, and publication datasets.
#
# 2. **Likert-Based Classification**
#    - Evaluate publications against FOA and grant objectives using LLMs.
#    - Annotate publications with Likert scores and detailed rationales.
#
# **Author:** Peter W. Rose ([pwrose@ucsd.edu](mailto:pwrose@ucsd.edu))
# **Date:** 2025-03-13

# %%
import os
from pathlib import Path
import glob
import json
import time
import pandas as pd

import llm_utils

# %% [markdown]
# ## Specify the LLM Model
# Run this notebook multiple times to evaluate publications using different LLM models.
# Uncomment the desired model for each run.

# %%
# model = "meta-llama/Llama-3.3-70B-Instruct"
model = "deepseek-ai/DeepSeek-R1-Distill-Qwen-32B"
# model = "gpt-4o-mini"

# %%
FOA_DIR = "../derived_data/foas" # Path to full-text FOA documents
DBGAP_ABSTRACTS = "../derived_data/dbgap_abstracts.csv" # dbGaP data
RADX_RAD_ALL = "../derived_data/publications_pubmed_raw.csv" # List of publications that mention RADx-rad grant numbers
LAST_UPDATE = "2025-06-02" # Date publications were last retrieved from PubMed

LENGTH_THRESHOLD = 100 # minimum length of title + abstract
ANNOTATION = "annotation_full_text_5" # Name of subfolder to save Likert scoring annotations
RESULTS = "../results"

# %% [markdown]
# ## 1. **Data Integration**
# Load and merge the preprocessed FOA, dbGaP, and Publication data

# %% [markdown]
# ### Load Funding Opportunity Announcement Documents for the RADx-rad Program

# %%
foas = pd.concat(
    (pd.read_csv(f).assign(sub_project=f.stem) for f in Path(FOA_DIR).glob("*.csv")),
    ignore_index=True
)
foas
# Out:
#               id                                               name  \
# 0  RFA-OD-20-017  Emergency Awards RADx-RAD: Screening for COVID...
# 1  RFA-OD-20-015  Emergency Awards: RADx-rad Wastewater Detectio...
# 2  RFA-OD-20-016  Emergency Awards: RADx-RAD Multimodal COVID-19...
# 3  RFA-OD-20-022  Emergency Awards: Chemosensory Testing as a CO...
# 4  RFA-OD-20-014  Emergency Awards: Automatic Detection and Trac...
# 5  RFA-OD-20-023  Emergency Awards: RADx-rad Predicting Viral-As...
# 6  RFA-OD-20-021  Emergency Awards RADx-RAD: Novel Biosensing fo...
# 7  RFA-OD-20-018  Emergency Awards: Exosome-based Non-traditiona...
#
#                                                  url  \
# 0  https://grants.nih.gov/grants/guide/rfa-files/...
# 1  https://grants.nih.gov/grants/guide/rfa-files/...
# 2  https://grants.nih.gov/grants/guide/rfa-files/...
# 3  https://grants.nih.gov/grants/guide/rfa-files/...
# 4  https://grants.nih.gov/grants/guide/rfa-files/...
# 5  https://grants.nih.gov/grants/guide/rfa-files/...
# 6  https://grants.nih.gov/grants/guide/rfa-files/...
# 7  https://grants.nih.gov/grants/guide/rfa-files/...
#
#                      sub_project  \
# 0                          SCENT
# 1                     Wastewater
# 2        Multimodal Surveillance
# 3           Chemosensory Testing
# 4  Automatic Detection & Tracing
# 5                   PreVAIL kIds
# 6       Novel Biosensing and VOC
# 7                        Exosome
#
#                                              summary
# 0  EXPIRED/nNational Institutes of Health (NIH)/n...
# 1  EXPIRED/nNational Institutes of Health (NIH)/n...
# 2  EXPIRED/nNational Institutes of Health (NIH)/n...
# 3  EXPIRED/nNational Institutes of Health (NIH)/n...
# 4  EXPIRED/nNational Institutes of Health (NIH)/n...
# 5  EXPIRED/nNational Institutes of Health (NIH)/n...
# 6  EXPIRED/nNational Institutes of Health (NIH)/n...
# 7  EXPIRED/nNational Institutes of Health (NIH)/n...

# %% [markdown]
# ### Load dbGaP Titles and Abstracts for the RADx-rad Program

# %%
dbgap_abstracts = pd.read_csv(DBGAP_ABSTRACTS, dtype=str, keep_default_na=False)
dbgap_abstracts.rename(columns={ "title": "dbgap_title", "description": "dbgap_abstract"}, inplace=True)
dbgap_abstracts.head(1)
# Out:
#        project_num  dbgap_accession research_initiative  \
# 0  1U01HL152410-01  phs002522.v1.p1            RADx-rad
#
#                 sub_project project_serial_num  \
# 0  Novel Biosensing and VOC           HL152410
#
#                                          dbgap_title     focus  \
# 0  Rapid Acceleration of Diagnostics - Radical (R...  COVID-19
#
#                                       dbgap_abstract
# 0  This proposal describes the design, fabricatio...

# %% [markdown]
# ### Load List of Publications that mention RADx-rad Grant Numbers

# %%
publications = pd.read_csv(RADX_RAD_ALL, usecols=["pm_id", "pmc_id", "doi", "title", "abstract", "keywords", "journal", "year", "authors", "article_type", "project_serial_num", "award_type", "supplement", "sub_project"], dtype=str, keep_default_na=False)

# %%
print(f"Number of publications: {publications.shape[0]}")
# Out:
# Number of publications: 689

# %% [markdown]
# ### Map the Publications to corresponding dbGaP Studies

# %%
publications = publications.merge(dbgap_abstracts, on=["project_serial_num", "sub_project"])
print(f"Number of publications: {publications.shape[0]}")
publications.drop_duplicates(inplace=True)
publications.head()
# Out:
# Number of publications: 801
#       pm_id       pmc_id                             doi  \
# 0  39773555  PMC11827850           doi:10.1172/JCI188222
# 1  39880798  PMC11800485      doi:10.1093/femsec/fiaf010
# 2  39948059  PMC11874078          doi:10.1002/wnan.70004
# 3  40101747  PMC11952872      doi:10.1093/jimmun/vkaf006
# 4  39724424  PMC11995861  doi:10.1007/s00216-024-05720-z
#
#                                                title  \
# 0  CXCL12 ameliorates neutrophilia and disease se...
# 1  Distinct bacteria display genus and species-sp...
# 2  Nanoparticle Contrast Agents for Photon-Counti...
# 3  A genetically modulated Toll-like receptor-tol...
# 4  Bioreactor contamination monitoring using off-...
#
#                                             abstract  \
# 0  Neutrophils, particularly low-density neutroph...
# 1  Lichens are complex symbiotic systems where fu...
# 2  The clinical availability of photon-counting c...
# 3  Dysregulated innate immune responses contribut...
# 4  Metabolically active cells emit volatile organ...
#
#                                             keywords  \
# 0  Angiotensin-Converting Enzyme 2|Animals|COVID-...
# 1  Bacteria|Colombia|Fungi|Lichens|Microbiota|Phy...
# 2  Animals|Contrast Media|Humans|Nanoparticles|Ph...
# 3  LYST|MIS-C|SARS-CoV-2|genetic variants|hyperin...
# 4  Animals|Aspergillus fumigatus|Biomanufacturing...
#
#                                              authors  \
# 0  Zheng, Jian|Dhakal, Hima|Qing, Enya|Shrestha, ...
# 1  Chaib De Mares, Maryam|Arciniegas Castro, Emer...
# 2  Devkota, Laxman|Bhavane, Rohan|Badea, Cristian...
# 3  Khan, Rehan|Ji, Weizhen|Guzman Rivera, Jeisac|...
# 4  Linderholm, Angela L|Bhandari, Manohar P|Borra...
#
#                                              journal  year  \
# 0              The Journal of clinical investigation  2025
# 1                          FEMS microbiology ecology  2025
# 2  Wiley interdisciplinary reviews. Nanomedicine ...  2025
# 3      Journal of immunology (Baltimore, Md. : 1950)  2025
# 4             Analytical and bioanalytical chemistry  2025
#
#              article_type project_serial_num award_type supplement  \
# 0         Journal Article           TR003787        U18      False
# 1         Journal Article           DA053941        U01      False
# 2  Journal Article|Review           HD105593        R61      False
# 3         Journal Article           HD105593        R61      False
# 4         Journal Article           TR003795        U18      False
#
#     sub_project      project_num  dbgap_accession research_initiative  \
# 0         SCENT  1U18TR003787-01  phs002563.v1.p1            RADx-rad
# 1    Wastewater  1U01DA053941-01  phs002525.v1.p1            RADx-rad
# 2  PreVAIL kIds  1R61HD105593-01  phs002585.v1.p1            RADx-rad
# 3  PreVAIL kIds  1R61HD105593-01  phs002585.v1.p1            RADx-rad
# 4         SCENT  1U18TR003795-01  phs002600.v1.p1            RADx-rad
#
#                                          dbgap_title     focus  \
# 0  Rapid Acceleration of Diagnostics - Radical (R...  COVID-19
# 1  Rapid Acceleration of Diagnostics - Radical (R...  COVID-19
# 2  Rapid Acceleration of Diagnostics - Radical (R...  COVID-19
# 3  Rapid Acceleration of Diagnostics - Radical (R...  COVID-19
# 4  Rapid Acceleration of Diagnostics - Radical (R...  COVID-19
#
#                                       dbgap_abstract
# 0  The COVID-19 pandemic has caused unprecedented...
# 1  The University of Miami (UM), with three prima...
# 2  This work is directed at characterizing pediat...
# 3  This work is directed at characterizing pediat...
# 4  The data herein combines GC-MS and GC-DMS anal...

# %%
publications[publications["pmc_id"] == "PMC10784670"]
# Out:
#         pm_id       pmc_id                               doi  \
# 177  38222877  PMC10784670  doi:10.1016/j.conctc.2023.101246
#
#                                                  title  \
# 177  Moana: Alternate surveillance for COVID-19 in ...
#
#                                               abstract keywords  \
# 177  Objective: Create a longitudinal, multi-modal ...
#
#                                                authors  \
# 177  Morgan ER|Dillard D|Lofgren E|Maddison BK|Rikl...
#
#                          journal  year     article_type project_serial_num  \
# 177  Contemp Clin Trials Commun.  2023  Journal Article           MD016526
#
#     award_type supplement              sub_project      project_num  \
# 177        R01      False  Multimodal Surveillance  1R01MD016526-01
#
#      dbgap_accession research_initiative  \
# 177  phs002551.v1.p1            RADx-rad
#
#                                            dbgap_title     focus  \
# 177  Rapid Acceleration of Diagnostics - Radical (R...  COVID-19
#
#                                         dbgap_abstract
# 177  Marshallese Pacific Islanders bear a dispropor...

# %% [markdown]
# ### Map the publications to the corresponding FOAs

# %%
publications = publications.merge(foas, on="sub_project")
print(f"Number of publications: {publications.shape[0]}")
publications.head()
# Out:
# Number of publications: 801
#       pm_id       pmc_id                             doi  \
# 0  39773555  PMC11827850           doi:10.1172/JCI188222
# 1  39880798  PMC11800485      doi:10.1093/femsec/fiaf010
# 2  39948059  PMC11874078          doi:10.1002/wnan.70004
# 3  40101747  PMC11952872      doi:10.1093/jimmun/vkaf006
# 4  39724424  PMC11995861  doi:10.1007/s00216-024-05720-z
#
#                                                title  \
# 0  CXCL12 ameliorates neutrophilia and disease se...
# 1  Distinct bacteria display genus and species-sp...
# 2  Nanoparticle Contrast Agents for Photon-Counti...
# 3  A genetically modulated Toll-like receptor-tol...
# 4  Bioreactor contamination monitoring using off-...
#
#                                             abstract  \
# 0  Neutrophils, particularly low-density neutroph...
# 1  Lichens are complex symbiotic systems where fu...
# 2  The clinical availability of photon-counting c...
# 3  Dysregulated innate immune responses contribut...
# 4  Metabolically active cells emit volatile organ...
#
#                                             keywords  \
# 0  Angiotensin-Converting Enzyme 2|Animals|COVID-...
# 1  Bacteria|Colombia|Fungi|Lichens|Microbiota|Phy...
# 2  Animals|Contrast Media|Humans|Nanoparticles|Ph...
# 3  LYST|MIS-C|SARS-CoV-2|genetic variants|hyperin...
# 4  Animals|Aspergillus fumigatus|Biomanufacturing...
#
#                                              authors  \
# 0  Zheng, Jian|Dhakal, Hima|Qing, Enya|Shrestha, ...
# 1  Chaib De Mares, Maryam|Arciniegas Castro, Emer...
# 2  Devkota, Laxman|Bhavane, Rohan|Badea, Cristian...
# 3  Khan, Rehan|Ji, Weizhen|Guzman Rivera, Jeisac|...
# 4  Linderholm, Angela L|Bhandari, Manohar P|Borra...
#
#                                              journal  year  \
# 0              The Journal of clinical investigation  2025
# 1                          FEMS microbiology ecology  2025
# 2  Wiley interdisciplinary reviews. Nanomedicine ...  2025
# 3      Journal of immunology (Baltimore, Md. : 1950)  2025
# 4             Analytical and bioanalytical chemistry  2025
#
#              article_type  ...      project_num  dbgap_accession  \
# 0         Journal Article  ...  1U18TR003787-01  phs002563.v1.p1
# 1         Journal Article  ...  1U01DA053941-01  phs002525.v1.p1
# 2  Journal Article|Review  ...  1R61HD105593-01  phs002585.v1.p1
# 3         Journal Article  ...  1R61HD105593-01  phs002585.v1.p1
# 4         Journal Article  ...  1U18TR003795-01  phs002600.v1.p1
#
#   research_initiative                                        dbgap_title  \
# 0            RADx-rad  Rapid Acceleration of Diagnostics - Radical (R...
# 1            RADx-rad  Rapid Acceleration of Diagnostics - Radical (R...
# 2            RADx-rad  Rapid Acceleration of Diagnostics - Radical (R...
# 3            RADx-rad  Rapid Acceleration of Diagnostics - Radical (R...
# 4            RADx-rad  Rapid Acceleration of Diagnostics - Radical (R...
#
#       focus                                     dbgap_abstract             id  \
# 0  COVID-19  The COVID-19 pandemic has caused unprecedented...  RFA-OD-20-017
# 1  COVID-19  The University of Miami (UM), with three prima...  RFA-OD-20-015
# 2  COVID-19  This work is directed at characterizing pediat...  RFA-OD-20-023
# 3  COVID-19  This work is directed at characterizing pediat...  RFA-OD-20-023
# 4  COVID-19  The data herein combines GC-MS and GC-DMS anal...  RFA-OD-20-017
#
#                                                 name  \
# 0  Emergency Awards RADx-RAD: Screening for COVID...
# 1  Emergency Awards: RADx-rad Wastewater Detectio...
# 2  Emergency Awards: RADx-rad Predicting Viral-As...
# 3  Emergency Awards: RADx-rad Predicting Viral-As...
# 4  Emergency Awards RADx-RAD: Screening for COVID...
#
#                                                  url  \
# 0  https://grants.nih.gov/grants/guide/rfa-files/...
# 1  https://grants.nih.gov/grants/guide/rfa-files/...
# 2  https://grants.nih.gov/grants/guide/rfa-files/...
# 3  https://grants.nih.gov/grants/guide/rfa-files/...
# 4  https://grants.nih.gov/grants/guide/rfa-files/...
#
#                                              summary
# 0  EXPIRED/nNational Institutes of Health (NIH)/n...
# 1  EXPIRED/nNational Institutes of Health (NIH)/n...
# 2  EXPIRED/nNational Institutes of Health (NIH)/n...
# 3  EXPIRED/nNational Institutes of Health (NIH)/n...
# 4  EXPIRED/nNational Institutes of Health (NIH)/n...
#
# [5 rows x 24 columns]

# %%
publications[publications["pmc_id"] == "PMC10784670"]
# Out:
#         pm_id       pmc_id                               doi  \
# 177  38222877  PMC10784670  doi:10.1016/j.conctc.2023.101246
#
#                                                  title  \
# 177  Moana: Alternate surveillance for COVID-19 in ...
#
#                                               abstract keywords  \
# 177  Objective: Create a longitudinal, multi-modal ...
#
#                                                authors  \
# 177  Morgan ER|Dillard D|Lofgren E|Maddison BK|Rikl...
#
#                          journal  year     article_type  ...      project_num  \
# 177  Contemp Clin Trials Commun.  2023  Journal Article  ...  1R01MD016526-01
#
#      dbgap_accession research_initiative  \
# 177  phs002551.v1.p1            RADx-rad
#
#                                            dbgap_title     focus  \
# 177  Rapid Acceleration of Diagnostics - Radical (R...  COVID-19
#
#                                         dbgap_abstract             id  \
# 177  Marshallese Pacific Islanders bear a dispropor...  RFA-OD-20-016
#
#                                                   name  \
# 177  Emergency Awards: RADx-RAD Multimodal COVID-19...
#
#                                                    url  \
# 177  https://grants.nih.gov/grants/guide/rfa-files/...
#
#                                                summary
# 177  EXPIRED/nNational Institutes of Health (NIH)/n...
#
# [1 rows x 24 columns]

# %% [markdown]
# ## Run the LLM to evaluate Publications against FOA and Grant Objectives

# %%
prompt = '''
You are a researcher analyzing scientific publications. You will be provided with a FUNDING OPPORTUNITY description, a GRANT ABSTRACT, and a PUBLICATION ABSTRACT. 
Your task is to determine whether the publication is related to the research objectives of the funding opportunity and/or the objectives stated in the grant abstract. 
If the publication abstract is missing, use the title but only if it clearly matches the objectives.
Please provide your answer as a JSON object following these guidelines:

Rank your response based on the following Likert scale:
1: Strongly disagree
2: Disagree
3: Neither agree nor disagree
4: Agree
5: Strongly agree

- result: integer 1 to 5 on the Likert scale to indicate if the publication is related to the funding opportunity and/or the grant description.
- explanation: A clear, concise, and specific explanation of how you arrived at your conclusion. The explanation should describe why the publication is or is not relevant to the research objectives in the funding opportunity and grant's abstract.

Example JSON response:

```json
{
  "result": 5,
  "explanation": "The publication directly addresses the specific research aims and methodology outlined in the funding opportunity and grant's abstract."
}
'''

# %% [markdown]
# The response format directs the LLM to return the results in the proper JSON format.

# %%
response_format = {
    "type": "json_schema",
    "json_schema": {
        "name": "Likert-5",
        "schema": {
            "type": "object",
            "properties": {
                "result": {"type": "integer"},
                "explanation": {"type": "string"},
            },
            "required": ["result", "explanation"],
            "additionalProperties": False
        },
        "strict": True
    }
}

# %%
def eval_publication(row, model): 
    pm_id = row["pm_id"]
    dbgap_accession = row["dbgap_accession"]
    doi = row["doi"].replace("doi:", "").replace("/", "_")

    identifier = f"{pm_id}_{doi}_{dbgap_accession}"

    # Remove model prefixes such as meta-llama from the model string
    simple_model = model.split('/', 1)[-1]
    result_path = os.path.join(RESULTS, simple_model, ANNOTATION)
    os.makedirs(result_path, exist_ok=True)

    # Check if the result file already exists, then skip this record
    result_file = os.path.join(result_path, f"{identifier}.csv")
    if os.path.isfile(result_file):
        if (len(row["title"]) + len(row['abstract'])) < LENGTH_THRESHOLD:
            print(f"Remove {identifier}. Length of title + abstract < {LENGTH_THRESHOLD} characters")
            os.remove(result_file)
        return

    print(f"processing: {identifier}")

    if (len(row["title"]) + len(row['abstract'])) < LENGTH_THRESHOLD:
        print(f"Skipping {pm_id}. Length of title + abstract < {LENGTH_THRESHOLD} characters")
        return

    # If there is no abstract, use the title as the abstract to avoid LLM failures.
    publication_abstract = row['abstract']
    if publication_abstract == "":
        publication_abstract = row['title']

    # Create the context for the LLM
    context = f"FUNDING OPPORTUNITY:\n{row['summary']}\n\nGRANT ABSTRACT:\n{row['dbgap_title']}\n{row['dbgap_abstract']}\n\nPUBLICATION ABSTRACT:\n{row['title']}\n{publication_abstract}"
    start = time.time()
    #print(context)
    
    # Run the LLM
    response, usage = llm_utils.run_prompt(prompt, context, model, environment="development", response_format=response_format)
    end = time.time()

    # Parse the response
    data = json.loads(response)
    result = data.get("result", "1")
    explanation = data.get("explanation", "")

    # Get token usage and calculate cost  
    completion_tokens = usage["completion_tokens"]
    prompt_tokens = usage["prompt_tokens"]

    cost = llm_utils.get_token_cost(prompt_tokens, model, "input")
    cost += llm_utils.get_token_cost(completion_tokens, model, "output")

    # Collect result data
    elapsed_time = f"{end-start:.1f}"
    result_data = {
        'result': [result],
        'explanation': [explanation],
        'model': [simple_model],
        'prompt_tokens': [prompt_tokens],
        'completion_tokens': [completion_tokens],
        'elapsed_time': [elapsed_time],
        'cost': [cost]
    }

    # Append the result data to each row 
    pub_data = row.to_dict()
    merged_data = pub_data | result_data

    # Create and save the DataFrame
    df = pd.DataFrame(merged_data)
    df.to_csv(result_file, index=False)
    return

# %%
publications.apply(eval_publication, model=model, axis=1)
# Out:
# processing: 39793745_10.1016_j.actbio.2025.01.006_phs002583.v1.p1
# processing: 38598791_10.1513_AnnalsATS.202310-896PS_phs002689.v1.p1
# Skipping 38598791. Length of title + abstract < 100 characters
# processing: 39078251_10.1513_AnnalsATS.202403-322PS_phs002689.v1.p1
# Skipping 39078251. Length of title + abstract < 100 characters
# processing: 37738417_10.1093_infdis_jiad405_phs002603.v1.p1
# Skipping 37738417. Length of title + abstract < 100 characters
# processing: 37738417_10.1093_infdis_jiad405_phs002603.v1.p1
# Skipping 37738417. Length of title + abstract < 100 characters
# processing: 37699143_10.1164_rccm.202308-1493ED_phs002689.v1.p1
# Skipping 37699143. Length of title + abstract < 100 characters
# processing: 36795031_10.2215_CJN.0000000000000089_phs002657.v1.p1
# Skipping 36795031. Length of title + abstract < 100 characters
# processing: 37159952_10.1513_AnnalsATS.202301-090RL_phs002689.v1.p1
# Skipping 37159952. Length of title + abstract < 100 characters
# processing: 36356276_10.2105_AJPH.2022.307141_phs002542.v1.p1
# Skipping 36356276. Length of title + abstract < 100 characters
# processing: 36947454_10.1056_NEJMc2215074_phs002945.v1.p1
# Skipping 36947454. Length of title + abstract < 100 characters
# processing: 35102392_10.1542_hpeds.2021-006466_phs002945.v1.p1
# Skipping 35102392. Length of title + abstract < 100 characters
# processing: 35598619_10.1016_S0140-6736(22)00743-7_phs002679.v1.p1
# Skipping 35598619. Length of title + abstract < 100 characters
# processing: 35439401_10.1515_cclm-2022-0082_phs002585.v1.p1
# Skipping 35439401. Length of title + abstract < 100 characters
# processing: 35876128_10.1164_rccm.202207-1337LE_phs002689.v1.p1
# Skipping 35876128. Length of title + abstract < 100 characters
# processing: 35466998_10.1093_eurheartj_ehac201_phs002561.v1.p1
# Skipping 35466998. Length of title + abstract < 100 characters
# processing: 35466998_10.1093_eurheartj_ehac201_phs002602.v1.p1
# Skipping 35466998. Length of title + abstract < 100 characters
# processing: 35957814_10.3389_fendo.2022.977912_phs002569.v1.p1
# Skipping 35957814. Length of title + abstract < 100 characters
# processing: 35230433_10.1542_peds.2020-045948G_phs002569.v1.p1
# Skipping 35230433. Length of title + abstract < 100 characters
# processing: 35857409_10.1513_AnnalsATS.202205-467RL_phs002561.v1.p1
# Skipping 35857409. Length of title + abstract < 100 characters
# processing: 35857409_10.1513_AnnalsATS.202205-467RL_phs002602.v1.p1
# Skipping 35857409. Length of title + abstract < 100 characters
# processing: 35660163_10.1016_j.medj.2022.05.004_phs002642.v1.p1
# Skipping 35660163. Length of title + abstract < 100 characters
# processing: 35368385_10.1016_S2665-9913(22)00090-X_phs002603.v1.p1
# Skipping 35368385. Length of title + abstract < 100 characters
# processing: 35368385_10.1016_S2665-9913(22)00090-X_phs002603.v1.p1
# Skipping 35368385. Length of title + abstract < 100 characters
# processing: 34281959_10.1681_ASN.2021060812_phs002657.v1.p1
# Skipping 34281959. Length of title + abstract < 100 characters
# processing: 33685976_10.1681_ASN.2020121691_phs002657.v1.p1
# Skipping 33685976. Length of title + abstract < 100 characters
# processing: 34246436_10.1016_j.jaip.2021.04.052_phs002689.v1.p1
# Skipping 34246436. Length of title + abstract < 100 characters
# processing: 33833034_10.1183_13993003.04625-2020_phs002561.v1.p1
# Skipping 33833034. Length of title + abstract < 100 characters
# processing: 33833034_10.1183_13993003.04625-2020_phs002602.v1.p1
# Skipping 33833034. Length of title + abstract < 100 characters
# processing: 34433933_10.1038_s41563-021-01088-y_phs002573.v1.p1
# Skipping 34433933. Length of title + abstract < 100 characters
# processing: 34230102_10.1681_ASN.2021020161_phs002657.v1.p1
# Skipping 34230102. Length of title + abstract < 100 characters
# processing: 33276117_10.1016_j.anai.2020.11.018_phs002689.v1.p1
# Skipping 33276117. Length of title + abstract < 100 characters
# processing: 33067221__phs002585.v1.p1
# Skipping 33067221. Length of title + abstract < 100 characters
# processing: 32453600_10.1164_rccm.202004-1411ED_phs002561.v1.p1
# Skipping 32453600. Length of title + abstract < 100 characters
# processing: 32453600_10.1164_rccm.202004-1411ED_phs002602.v1.p1
# Skipping 32453600. Length of title + abstract < 100 characters
# processing: 30920923_10.1161_CIRCRESAHA.119.314403_phs002561.v1.p1
# Skipping 30920923. Length of title + abstract < 100 characters
# processing: 30920923_10.1161_CIRCRESAHA.119.314403_phs002602.v1.p1
# Skipping 30920923. Length of title + abstract < 100 characters
# processing: 27492841_10.1161_CIRCRESAHA.116.309394_phs002561.v1.p1
# Skipping 27492841. Length of title + abstract < 100 characters
# processing: 27492841_10.1161_CIRCRESAHA.116.309394_phs002602.v1.p1
# Skipping 27492841. Length of title + abstract < 100 characters
# processing: 26294733_10.3324_haematol.2015.132449_phs002561.v1.p1
# Skipping 26294733. Length of title + abstract < 100 characters
# processing: 26294733_10.3324_haematol.2015.132449_phs002602.v1.p1
# Skipping 26294733. Length of title + abstract < 100 characters
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 796    None
# 797    None
# 798    None
# 799    None
# 800    None
# Length: 801, dtype: object
