# %% [markdown]
# # 1_get_publications_pubmed
# This notebook retrieves publications from PubMed that mention a RADx-rad project (grant) number.
#
# **Author**: Peter W Rose ([pwrose@ucsd.edu](mailto:pwrose@ucsd.edu))
# **Date:** 2025-03-13
#
# TODO: Check for additional papers from Semantic Scholar by searching for PIs publications and checking for grant numbers.

# %%
import os
import pandas as pd
import ast
from datetime import datetime
import pubmed_query
import nih_utils

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# pd.set_option('display.max_colwidth', None)

# %%
DATA_PATH = "../data"
DERIVED_DATA_PATH = "../derived_data"

# %%
current_date = datetime.today().date()
print(f"Last update: {current_date}")
# Out:
# Last update: 2025-06-02

# %% [markdown]
# ## Get the list of RADx-rad Grants

# %%
projects = pd.read_csv(os.path.join(DATA_PATH, "grants.csv"))
projects.query("research_initiative == 'RADx-rad'", inplace=True)

# %% [markdown]
# ## Retrieve PubMed articles that mention RADx-rad project numbers
# Due to inconsistent specification of grant numbers in publication, we only use the last 8 characters of a grant number for the PubMed grant number search. The NIH Reporter refers to this number as the "project_serial_num" and this number is unique.
#
# The RADx-rad projects started towards the end of 2020, so the earliest publications
# are most likely to occur in 2021. By specifying the start year, false positives are minimized.
#
# False positive (non-RADx-rad related) publications arise because some awards share the same project serial number:
# 1. Some RADx-rad projects are supplements to another award.
# 2. Center grants fund a variety of projects, including RADx-rad projects.

# %%
projects["project_serial_num"] = projects["project_num"].apply(nih_utils.get_project_serial_num)
projects["award_type"] = projects["project_num"].apply(nih_utils.get_award_type)
projects["supplement"] = projects["project_num"].apply(nih_utils.is_supplement)
projects.fillna("", inplace=True)
projects.head()
# Out:
#        project_num research_initiative               sub_project  \
# 0  1U01DA053976-01            RADx-rad                Wastewater
# 1  1U24LM013755-01            RADx-rad  Data Coordinating Center
# 2  1U01HL152410-01            RADx-rad  Novel Biosensing and VOC
# 3  1R01NR020105-01            RADx-rad   Multimodal Surveillance
# 4  1R01DE031114-01            RADx-rad   Multimodal Surveillance
#
#                contact_pi                                    co_pis  \
# 0     Conroy-Ben, Otakuye            Halden, Rolf U|Hamilton, Kerry
# 1    Ohno-Machado, Lucila          Aronoff-Spencer, Eliah S|Xu, Hua
# 2          Fay, William P  Grant, Sheila Ann|Turpin, William Monroe
# 3       Snyder, Michael P
# 4  Jokerst, Jesse Vincent
#
#                                        comments project_serial_num award_type  \
# 0  AI/AN governed by the Tribal Data Repository           DA053976        U01
# 1             RADx-rad Data Coordination Center           LM013755        U24
# 2                                                         HL152410        U01
# 3                                                         NR020105        R01
# 4                                                         DE031114        R01
#
#    supplement
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
#start_year = 2020
start_year = 1900
end_year = 2100

# %%
grant_list = projects["project_serial_num"].unique()
publications = pubmed_query.get_pubmed_data_new(grant_list, start_year, end_year)
publications.rename(columns={"grant_number": "project_serial_num"}, inplace=True)
publications["doi"] = "doi:" + publications["doi"]
# Out:
# Processed grant DA053976: 2 publications
# Processed grant LM013755: 28 publications
# Processed grant HL152410: 13 publications
# Processed grant NR020105: 5 publications
# Processed grant DE031114: 21 publications
# Processed grant DA053941: 38 publications
# Processed grant LM013129: 24 publications
# Processed grant DA053903: 9 publications
# Processed grant AA029324: 0 publications
# Processed grant TR003778: 30 publications
# Processed grant AA029328: 9 publications
# Processed grant HD105610: 11 publications
# Processed grant DE030841: 0 publications
# Processed grant MD016526: 0 publications
# Processed grant HD105590: 17 publications
# Processed grant TR003787: 20 publications
# Processed grant AA029316: 4 publications
# Processed grant HD105619: 16 publications
# Processed grant DE030829: 2 publications
# Processed grant DE030832: 6 publications
# Processed grant AA029348: 18 publications
# Processed grant HL150852: 42 publications
# Processed grant HD105593: 29 publications
# Processed grant TR003775: 1 publications
# Processed grant TR003795: 23 publications
# Processed grant HL119145: 125 publications
# Processed grant HD105594: 18 publications
# Processed grant DA053949: 5 publications
# Processed grant HD105613: 11 publications
# Processed grant DC019573: 8 publications
# Processed grant DC016112: 7 publications
# Processed grant DK130067: 26 publications
# Processed grant DA053893: 15 publications
# Processed grant DE030852: 9 publications
# Processed grant HL146002: 45 publications
# Processed grant DC019578: 15 publications
# Processed grant AA029331: 2 publications
# Processed grant DE030842: 0 publications
# Processed grant TR003807: 5 publications
# Processed grant DA053899: 6 publications
# Processed grant AA029345: 8 publications
# Processed grant TR003812: 3 publications
# Processed grant TR003793: 5 publications
# Processed grant HD105618: 7 publications
# Processed grant ES103366: 0 publications
# Processed grant HL152401: 10 publications
# Processed grant HD105591: 11 publications
# Processed grant DC019579: 4 publications
# Processed grant TR003780: 7 publications

# %%
publications.columns
# Out:
# Index(['pm_id', 'pmc_id', 'doi', 'title', 'abstract', 'keywords', 'mesh_ids',
#        'mesh_terms', 'authors', 'journal', 'year', 'publication_date',
#        'article_type', 'project_serial_num'],
#       dtype='object')

# %%
publications.head()
# Out:
#       pm_id       pmc_id                               doi  \
# 0  38936269  PMC11657630  doi:10.1016/j.watres.2024.121858
# 1  34520666   PMC8495893       doi:10.1021/acs.est.1c02580
# 2  40332956                      doi:10.1093/jamia/ocaf064
# 3  39613846  PMC11607336    doi:10.1038/s41598-024-81170-y
# 4  38832084  PMC11145658       doi:10.1145/3583780.3614739
#
#                                                title  \
# 0  Quantitative microbial risk assessment (QMRA) ...
# 1  Time: A Key Driver of Uncertainty When Assessi...
# 2  CDEMapper: enhancing National Institutes of He...
# 3  De-identification is not enough: a comparison ...
# 4  DiscoverPath: A Knowledge Refinement and Retri...
#
#                                             abstract  \
# 0  Wastewater treatment plants (WWTPs) provide vi...
# 1
# 2  Common Data Elements (CDEs) standardize data c...
# 3  For sharing privacy-sensitive data, de-identif...
# 4  The exponential growth in scholarly publicatio...
#
#                                             keywords  \
# 0  [Exposure modeling, Pathogenic microorganisms ...
# 1  [microplastic, nanoplastic, plastic pollution,...
# 2  [common data element, data collection, data sh...
# 3                                                 []
# 4  [Biomedical, Healthcare, Information Retrieval...
#
#                                             mesh_ids  \
# 0  [D018570, D006801, D062065, D016273, D014865, ...
# 1      [D004784, D006801, D010969, D035501, D014874]
# 2                                                 []
# 3  [D006801, D057286, D003219, D016494, D018907, ...
# 4                                                 []
#
#                                           mesh_terms  \
# 0  [Risk Assessment, Humans, Wastewater, Occupati...
# 1  [Environmental Monitoring, Humans, Plastics, U...
# 2                                                 []
# 3  [Humans, Electronic Health Records, Confidenti...
# 4                                                 []
#
#                                              authors  \
# 0  [Heida, Ashley, Maal-Bared, Rasha, Veillette, ...
# 1  [Halden, Rolf U, Rolsky, Charles, Khan, Farhan R]
# 2  [Wang, Yan, Huang, Jimin, He, Huan, Zhang, Vin...
# 3  [Sarkar, Atiquer Rahman, Chuang, Yao-Shun, Moh...
# 4  [Chuang, Yu-Neng, Wang, Guanchu, Chang, Chia-Y...
#
#                                              journal  year publication_date  \
# 0                                     Water research  2024       2024-08-15
# 1                 Environmental science & technology  2021       2021-10-05
# 2  Journal of the American Medical Informatics As...  2025       2025-05-07
# 3                                 Scientific reports  2024       2024-11-29
# 4  Proceedings of the ... ACM International Confe...  2023       2023-10-01
#
#                                         article_type project_serial_num
# 0                                  [Journal Article]           DA053976
# 1  [Journal Article, Research Support, N.I.H., Ex...           DA053976
# 2                                  [Journal Article]           LM013755
# 3               [Journal Article, Comparative Study]           LM013755
# 4                                  [Journal Article]           LM013755

# %% [markdown]
# ### Add Publications that are not in PubMed or do not contain the grant number

# %%
non_pubmed_publications = pd.read_csv(os.path.join(DATA_PATH, "publications_other.csv"), dtype=str, keep_default_na=False)

# %%
# Convert string representations to lists
def safe_split(value):
    return [item.strip() for item in value.strip("[]").split(",")] if value else []

columns_to_convert = ["keywords", "mesh_ids", "mesh_terms", "authors", "article_type"]
non_pubmed_publications[columns_to_convert] = non_pubmed_publications[columns_to_convert].map(safe_split)

# %%
non_pubmed_publications.head()
# Out:
#       pm_id       pmc_id                               doi  \
# 0                         doi:10.1109/ICHI54592.2022.00070
# 1                             doi:10.1021/acs.jpcc.2c06434
# 2  38222877  PMC10784670  doi:10.1016/j.conctc.2023.101246
#
#                                                title  \
# 0  IMI-CDE: an interactive interface for collabor...
# 1  Understanding Oligonucleotide Hybridization an...
# 2  Moana: Alternate surveillance for COVID-19 in ...
#
#                                             abstract  \
# 0  The National Institute of Health (NIH) launche...
# 1  Semiconducting single-walled carbon nanotubes ...
# 2  Objective: Create a longitudinal, multi-modal ...
#
#                                             keywords mesh_ids mesh_terms  \
# 0  [COVID-19, Common Data Element, CDE Mapping, D...       []         []
# 1  [Carbon nanotubes, Genetics, Hybridization, Qu...       []         []
# 2                                                 []       []         []
#
#                                              authors  \
# 0  [Tao S, Chou WC, Li J, Du J, Ram PM, Abeysingh...
# 1  [Cui J, Gong X, Cho S-Y, Jin X, Yang S, Khosra...
# 2  [Morgan ER, Dillard D, Lofgren E, Maddison BK,...
#
#                                              journal       article_type  year  \
# 0  2022 IEEE 10th International Conference on Hea...      [Proceedings]  2022
# 1                                      J Phys Chem C  [Journal Article]  2023
# 2                        Contemp Clin Trials Commun.  [Journal Article]  2023
#
#   project_serial_num Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0           LM013755
# 1           DE030829
# 2           MD016526
#
#   Unnamed: 17
# 0
# 1
# 2

# %%
publications = pd.concat([publications, non_pubmed_publications], ignore_index=True)
publications.fillna("", inplace=True)
print(f"Number of raw publications: {publications.shape[0]}")
# Out:
# Number of raw publications: 723

# %%
publications.tail()
# Out:
#         pm_id       pmc_id                                    doi  \
# 718  34646165   PMC8504676          doi:10.3389/fphys.2021.747789
# 719  34304585   PMC8363557  doi:10.1161/HYPERTENSIONAHA.120.16690
# 720                              doi:10.1109/ICHI54592.2022.00070
# 721                                  doi:10.1021/acs.jpcc.2c06434
# 722  38222877  PMC10784670       doi:10.1016/j.conctc.2023.101246
#
#                                                  title  \
# 718  Deciphering the Role of microRNAs in Large-Art...
# 719  Degradation of Premature-miR-181b by the Trans...
# 720  IMI-CDE: an interactive interface for collabor...
# 721  Understanding Oligonucleotide Hybridization an...
# 722  Moana: Alternate surveillance for COVID-19 in ...
#
#                                               abstract  \
# 718  Large artery stiffness (LAS) is a major, indep...
# 719                                [Figure: see text].
# 720  The National Institute of Health (NIH) launche...
# 721  Semiconducting single-walled carbon nanotubes ...
# 722  Objective: Create a longitudinal, multi-modal ...
#
#                                               keywords  \
# 718  [aging, arterial stiffness, miR-181b, microRNA...
# 719  [aorta, cardiovascular diseases, microRNA degr...
# 720  [COVID-19, Common Data Element, CDE Mapping, D...
# 721  [Carbon nanotubes, Genetics, Hybridization, Qu...
# 722                                                 []
#
#                                               mesh_ids  \
# 718                                                 []
# 719  [D000818, D001011, D001127, D004268, D051379, ...
# 720                                                 []
# 721                                                 []
# 722                                                 []
#
#                                             mesh_terms  \
# 718                                                 []
# 719  [Animals, Aorta, Arginine Vasopressin, DNA-Bin...
# 720                                                 []
# 721                                                 []
# 722                                                 []
#
#                                                authors  \
# 718  [Baraban, Jay M, Tuday, Eric, Berkowitz, Dan E...
# 719  [Tuday, Eric, Nakano, Mitsunori, Akiyoshi, Kei...
# 720  [Tao S, Chou WC, Li J, Du J, Ram PM, Abeysingh...
# 721  [Cui J, Gong X, Cho S-Y, Jin X, Yang S, Khosra...
# 722  [Morgan ER, Dillard D, Lofgren E, Maddison BK,...
#
#                                                journal  year publication_date  \
# 718                            Frontiers in physiology  2021       2021-01-01
# 719                 Hypertension (Dallas, Tex. : 1979)  2021       2021-09-01
# 720  2022 IEEE 10th International Conference on Hea...  2022
# 721                                      J Phys Chem C  2023
# 722                        Contemp Clin Trials Commun.  2023
#
#                                           article_type project_serial_num  \
# 718                          [Journal Article, Review]           TR003780
# 719  [Journal Article, Research Support, N.I.H., Ex...           TR003780
# 720                                      [Proceedings]           LM013755
# 721                                  [Journal Article]           DE030829
# 722                                  [Journal Article]           MD016526
#
#     Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17
# 718
# 719
# 720
# 721
# 722

# %%
publications = publications.merge(projects[["project_serial_num", "award_type", "supplement", "research_initiative", "sub_project"]], on="project_serial_num")
publications.tail()
# Out:
#         pm_id       pmc_id                                    doi  \
# 736  34646165   PMC8504676          doi:10.3389/fphys.2021.747789
# 737  34304585   PMC8363557  doi:10.1161/HYPERTENSIONAHA.120.16690
# 738                              doi:10.1109/ICHI54592.2022.00070
# 739                                  doi:10.1021/acs.jpcc.2c06434
# 740  38222877  PMC10784670       doi:10.1016/j.conctc.2023.101246
#
#                                                  title  \
# 736  Deciphering the Role of microRNAs in Large-Art...
# 737  Degradation of Premature-miR-181b by the Trans...
# 738  IMI-CDE: an interactive interface for collabor...
# 739  Understanding Oligonucleotide Hybridization an...
# 740  Moana: Alternate surveillance for COVID-19 in ...
#
#                                               abstract  \
# 736  Large artery stiffness (LAS) is a major, indep...
# 737                                [Figure: see text].
# 738  The National Institute of Health (NIH) launche...
# 739  Semiconducting single-walled carbon nanotubes ...
# 740  Objective: Create a longitudinal, multi-modal ...
#
#                                               keywords  \
# 736  [aging, arterial stiffness, miR-181b, microRNA...
# 737  [aorta, cardiovascular diseases, microRNA degr...
# 738  [COVID-19, Common Data Element, CDE Mapping, D...
# 739  [Carbon nanotubes, Genetics, Hybridization, Qu...
# 740                                                 []
#
#                                               mesh_ids  \
# 736                                                 []
# 737  [D000818, D001011, D001127, D004268, D051379, ...
# 738                                                 []
# 739                                                 []
# 740                                                 []
#
#                                             mesh_terms  \
# 736                                                 []
# 737  [Animals, Aorta, Arginine Vasopressin, DNA-Bin...
# 738                                                 []
# 739                                                 []
# 740                                                 []
#
#                                                authors  \
# 736  [Baraban, Jay M, Tuday, Eric, Berkowitz, Dan E...
# 737  [Tuday, Eric, Nakano, Mitsunori, Akiyoshi, Kei...
# 738  [Tao S, Chou WC, Li J, Du J, Ram PM, Abeysingh...
# 739  [Cui J, Gong X, Cho S-Y, Jin X, Yang S, Khosra...
# 740  [Morgan ER, Dillard D, Lofgren E, Maddison BK,...
#
#                                                journal  year publication_date  \
# 736                            Frontiers in physiology  2021       2021-01-01
# 737                 Hypertension (Dallas, Tex. : 1979)  2021       2021-09-01
# 738  2022 IEEE 10th International Conference on Hea...  2022
# 739                                      J Phys Chem C  2023
# 740                        Contemp Clin Trials Commun.  2023
#
#                                           article_type project_serial_num  \
# 736                          [Journal Article, Review]           TR003780
# 737  [Journal Article, Research Support, N.I.H., Ex...           TR003780
# 738                                      [Proceedings]           LM013755
# 739                                  [Journal Article]           DE030829
# 740                                  [Journal Article]           MD016526
#
#     Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 award_type  \
# 736                                                                    U18
# 737                                                                    U18
# 738                                                                    U24
# 739                                                                    R42
# 740                                                                    R01
#
#      supplement research_initiative               sub_project
# 736       False            RADx-rad                   Exosome
# 737       False            RADx-rad                   Exosome
# 738       False            RADx-rad  Data Coordinating Center
# 739       False            RADx-rad  Novel Biosensing and VOC
# 740       False            RADx-rad   Multimodal Surveillance

# %%
# Combine the keyword and MeSH term columns and create a vertical bar separated list
publications["keywords"] = publications.apply(lambda row: "|".join(sorted(set(row["keywords"] + row["mesh_terms"]))), axis=1)
publications.drop(columns=["mesh_ids", "mesh_terms"], inplace=True)

# %%
publications.fillna("", inplace=True)

# %%
# Convert lists into "|"-separated strings
publications["authors"] = publications.apply(lambda row: "|".join(row["authors"]), axis=1)
publications["article_type"] = publications.apply(lambda row: "|".join(sorted(row["article_type"])), axis=1)
publications.head()
# Out:
#       pm_id       pmc_id                               doi  \
# 0  38936269  PMC11657630  doi:10.1016/j.watres.2024.121858
# 1  34520666   PMC8495893       doi:10.1021/acs.est.1c02580
# 2  40332956                      doi:10.1093/jamia/ocaf064
# 3  39613846  PMC11607336    doi:10.1038/s41598-024-81170-y
# 4  38832084  PMC11145658       doi:10.1145/3583780.3614739
#
#                                                title  \
# 0  Quantitative microbial risk assessment (QMRA) ...
# 1  Time: A Key Driver of Uncertainty When Assessi...
# 2  CDEMapper: enhancing National Institutes of He...
# 3  De-identification is not enough: a comparison ...
# 4  DiscoverPath: A Knowledge Refinement and Retri...
#
#                                             abstract  \
# 0  Wastewater treatment plants (WWTPs) provide vi...
# 1
# 2  Common Data Elements (CDEs) standardize data c...
# 3  For sharing privacy-sensitive data, de-identif...
# 4  The exponential growth in scholarly publicatio...
#
#                                             keywords  \
# 0  Exposure modeling|Humans|Models, Theoretical|O...
# 1  Environmental Monitoring|Humans|Plastics|Uncer...
# 2  common data element|data collection|data shari...
# 3  Algorithms|Computer Security|Confidentiality|E...
# 4  Biomedical|Healthcare|Information Retrieval Sy...
#
#                                              authors  \
# 0  Heida, Ashley|Maal-Bared, Rasha|Veillette, Mar...
# 1      Halden, Rolf U|Rolsky, Charles|Khan, Farhan R
# 2  Wang, Yan|Huang, Jimin|He, Huan|Zhang, Vincent...
# 3  Sarkar, Atiquer Rahman|Chuang, Yao-Shun|Mohamm...
# 4  Chuang, Yu-Neng|Wang, Guanchu|Chang, Chia-Yuan...
#
#                                              journal  year publication_date  \
# 0                                     Water research  2024       2024-08-15
# 1                 Environmental science & technology  2021       2021-10-05
# 2  Journal of the American Medical Informatics As...  2025       2025-05-07
# 3                                 Scientific reports  2024       2024-11-29
# 4  Proceedings of the ... ACM International Confe...  2023       2023-10-01
#
#                                         article_type project_serial_num  \
# 0                                    Journal Article           DA053976
# 1  Journal Article|Research Support, N.I.H., Extr...           DA053976
# 2                                    Journal Article           LM013755
# 3                  Comparative Study|Journal Article           LM013755
# 4                                    Journal Article           LM013755
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 award_type  \
# 0                                                                    U01
# 1                                                                    U01
# 2                                                                    U24
# 3                                                                    U24
# 4                                                                    U24
#
#    supplement research_initiative               sub_project
# 0       False            RADx-rad                Wastewater
# 1       False            RADx-rad                Wastewater
# 2       False            RADx-rad  Data Coordinating Center
# 3       False            RADx-rad  Data Coordinating Center
# 4       False            RADx-rad  Data Coordinating Center

# %%
publications.drop_duplicates(inplace=True)

# %% [markdown]
# ### Assign article type for preprints

# %%
preprint_journals = {"ArXiv", "bioRxiv", "medRxiv", "Res Sq"}
publications["article_type"] = publications.apply(
    lambda row: "Preprint" if row["journal"] in preprint_journals else row["article_type"],
    axis=1
)

# %% [markdown]
# ### Order articles in priority order in preparation for duplicate removal
# * Journal articles have highest priority
# * Other article types have a lower priority (e.g., Letters, Reviews)
# * Preprints or article corrections have the lowest priority
# * Newer publications (by year) have priority

# %%
def get_priority(article_type):
    if "Journal Article" in article_type:
        return 2
    if "Preprint" in article_type:
        return 0
    return 1

publications["type_priority"] = publications["article_type"].apply(get_priority)
publications = publications.sort_values(by=["year", "type_priority"], ascending=[False, False])

# %%
print(publications.shape[0])
publications.query("pm_id == '38859985'")
# Out:
# 741
#         pm_id       pmc_id                     doi  \
# 493  38859985  PMC11163376  doi:10.1093/ve/veae034
# 494  38859985  PMC11163376  doi:10.1093/ve/veae034
#
#                                                  title  \
# 493  Within-host influenza viral diversity in the p...
# 494  Within-host influenza viral diversity in the p...
#
#                                               abstract  \
# 493  Seasonal influenza virus predominantly evolves...
# 494  Seasonal influenza virus predominantly evolves...
#
#                                               keywords  \
# 493  antigenic drift|influenza|next-generation sequ...
# 494  antigenic drift|influenza|next-generation sequ...
#
#                                                authors          journal  year  \
# 493  Sobel Leonard, Ashley|Mendoza, Lydia|McFarland...  Virus evolution  2024
# 494  Sobel Leonard, Ashley|Mendoza, Lydia|McFarland...  Virus evolution  2024
#
#     publication_date     article_type project_serial_num Unnamed: 13  \
# 493       2024-01-01  Journal Article           HD105594
# 494       2024-01-01  Journal Article           HD105594
#
#     Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 award_type  supplement  \
# 493                                                        R61       False
# 494                                                        R33       False
#
#     research_initiative   sub_project  type_priority
# 493            RADx-rad  PreVAIL kIds              2
# 494            RADx-rad  PreVAIL kIds              2

# %%
publications.drop_duplicates(inplace=True)
print(publications.shape[0])
publications.query("pm_id == '38859985'") # This publication is related to two award_types: R61 and R33
# Out:
# 741
#         pm_id       pmc_id                     doi  \
# 493  38859985  PMC11163376  doi:10.1093/ve/veae034
# 494  38859985  PMC11163376  doi:10.1093/ve/veae034
#
#                                                  title  \
# 493  Within-host influenza viral diversity in the p...
# 494  Within-host influenza viral diversity in the p...
#
#                                               abstract  \
# 493  Seasonal influenza virus predominantly evolves...
# 494  Seasonal influenza virus predominantly evolves...
#
#                                               keywords  \
# 493  antigenic drift|influenza|next-generation sequ...
# 494  antigenic drift|influenza|next-generation sequ...
#
#                                                authors          journal  year  \
# 493  Sobel Leonard, Ashley|Mendoza, Lydia|McFarland...  Virus evolution  2024
# 494  Sobel Leonard, Ashley|Mendoza, Lydia|McFarland...  Virus evolution  2024
#
#     publication_date     article_type project_serial_num Unnamed: 13  \
# 493       2024-01-01  Journal Article           HD105594
# 494       2024-01-01  Journal Article           HD105594
#
#     Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 award_type  supplement  \
# 493                                                        R61       False
# 494                                                        R33       False
#
#     research_initiative   sub_project  type_priority
# 493            RADx-rad  PreVAIL kIds              2
# 494            RADx-rad  PreVAIL kIds              2

# %%
publications.query("pm_id == '35532905'") # Matches two different grant numbers
# Out:
#         pm_id      pmc_id                               doi  \
# 25   35532905  PMC9112978  doi:10.1021/acs.analchem.2c00554
# 229  35532905  PMC9112978  doi:10.1021/acs.analchem.2c00554
#
#                                                  title  \
# 25   Aptamer Sandwich Lateral Flow Assay (AptaFlow)...
# 229  Aptamer Sandwich Lateral Flow Assay (AptaFlow)...
#
#                                               abstract  \
# 25   The COVID-19 pandemic is among the greatest he...
# 229  The COVID-19 pandemic is among the greatest he...
#
#                                               keywords  \
# 25   Antibodies, Viral|Aptamers, Nucleotide|COVID-1...
# 229  Antibodies, Viral|Aptamers, Nucleotide|COVID-1...
#
#                                                authors               journal  \
# 25   Yang, Lucy F|Kacherovsky, Nataly|Panpradist, N...  Analytical chemistry
# 229  Yang, Lucy F|Kacherovsky, Nataly|Panpradist, N...  Analytical chemistry
#
#      year publication_date                                       article_type  \
# 25   2022       2022-05-24  Journal Article|Research Support, N.I.H., Extr...
# 229  2022       2022-05-24  Journal Article|Research Support, N.I.H., Extr...
#
#     project_serial_num Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 25            LM013755
# 229           AA029316
#
#     Unnamed: 17 award_type  supplement research_initiative  \
# 25                     U24       False            RADx-rad
# 229                    U01       False            RADx-rad
#
#                        sub_project  type_priority
# 25        Data Coordinating Center              2
# 229  Automatic Detection & Tracing              2

# %%
publications.query("pm_id == '38127053'") # Matches two different grant numbers
# Out:
#         pm_id       pmc_id                           doi  \
# 257  38127053  PMC11001522  doi:10.1021/acs.jcim.3c00713
# 603  38127053  PMC11001522  doi:10.1021/acs.jcim.3c00713
#
#                                                  title  \
# 257  APIPred: An XGBoost-Based Method for Predictin...
# 603  APIPred: An XGBoost-Based Method for Predictin...
#
#                                               abstract  \
# 257  Aptamers are single-stranded DNA or RNA oligos...
# 603  Aptamers are single-stranded DNA or RNA oligos...
#
#                                               keywords  \
# 257  Aptamers, Nucleotide|Molecular Docking Simulat...
# 603  Aptamers, Nucleotide|Molecular Docking Simulat...
#
#                                                authors  \
# 257  Fang, Zheng|Wu, Zhongqi|Wu, Xinbo|Chen, Shixin...
# 603  Fang, Zheng|Wu, Zhongqi|Wu, Xinbo|Chen, Shixin...
#
#                                           journal  year publication_date  \
# 257  Journal of chemical information and modeling  2024       2024-04-08
# 603  Journal of chemical information and modeling  2024       2024-04-08
#
#                                           article_type project_serial_num  \
# 257  Journal Article|Research Support, N.I.H., Extr...           AA029348
# 603  Journal Article|Research Support, N.I.H., Extr...           DE030852
#
#     Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 award_type  \
# 257                                                                    U01
# 603                                                                    R44
#
#      supplement research_initiative                    sub_project  \
# 257       False            RADx-rad  Automatic Detection & Tracing
# 603       False            RADx-rad       Novel Biosensing and VOC
#
#      type_priority
# 257              2
# 603              2

# %%
import pandas as pd
from Levenshtein import ratio

# Initialize an empty list to store indices of rows to keep
rows_to_keep = []

# Loop through the DataFrame and check for similar titles
for i, row in publications.iterrows():
    # Check if current title is similar to any titles in rows_to_keep
    similar_found = False
    for keep_idx in rows_to_keep:
        # Calculate similarity ratio
        similarity = ratio(row["title"], publications.loc[keep_idx, "title"])
        # Check if they have the same project number
        same_project_num = row["project_serial_num"] == publications.loc[keep_idx, "project_serial_num"]
        
        # If similar, break out of the loop
        #if similarity > 0.95 and same_project_num:
        if similarity > 0.80 and same_project_num:
            similar_found = True
            print("found similar paper:")
            print(row["title"])
            print(publications.loc[keep_idx, "title"])
            break
    
    # If no similar title was found, add the index to rows_to_keep
    if not similar_found:
        rows_to_keep.append(i)

# Filter the DataFrame to only include rows we want to keep
publications = publications.loc[rows_to_keep].drop(columns="type_priority").reset_index(drop=True)
print(f"Number of raw publications after eliminating duplicate titles: {publications.shape[0]}")
# Out:
# found similar paper:
# A genetically modulated Toll-like-receptor-tolerant phenotype in peripheral blood cells of children with multisystem inflammatory syndrome.
# A genetically modulated Toll-like receptor-tolerant phenotype in peripheral blood cells of children with multisystem inflammatory syndrome.
# found similar paper:
# Structurally-informed human interactome reveals proteome-wide perturbations by disease mutations.
# A structurally informed human protein-protein interactome reveals proteome-wide perturbations caused by disease mutations.
# found similar paper:
# Within-host influenza viral diversity in the pediatric population as a function of age, vaccine, and health status.
# Within-host influenza viral diversity in the pediatric population as a function of age, vaccine, and health status.
# found similar paper:
# Thinking Small, Stinking Big: The World of Microbial Odors.
# Thinking Small, Stinking Big: The World of Microbial Odors.
# found similar paper:
# Geospatially-resolved public-health surveillance via wastewater sequencing.
# Towards geospatially-resolved public-health surveillance via wastewater sequencing.
# found similar paper:
# Direct Detection of 4-Dimensions of SARS-CoV-2: Infection (vRNA), Infectivity (Antigen), Binding Antibody, and Functional Neutralizing Antibody in Saliva.
# Direct detection of 4-dimensions of SARS-CoV-2: infection (vRNA), infectivity (antigen), binding antibody, and functional neutralizing antibody in saliva.
# found similar paper:
# Self-assembly of DNA nanostructures in different cations.
# Self-Assembly of DNA Nanostructures in Different Cations.
# found similar paper:
# Characterization of the microbiome and volatile compounds in anal gland secretions from domestic cats (Felis catus) using metagenomics and metabolomics.
# Characterization of the microbiome and volatile compounds in anal gland secretions from domestic cats (Felis catus) using metagenomics and metabolomics.
# found similar paper:
# Developmental progression of the nasopharyngeal microbiome during childhood and association with the lower airway microbiome.
# Developmental progression of the nasopharyngeal microbiome during childhood and association with the lower airway microbiome.
# found similar paper:
# Transient loss and recovery of oral chemesthesis, taste and smell with COVID-19: a small case-control series.
# Transient loss and recovery of oral chemesthesis, taste and smell with COVID-19: A small case-control series.
# found similar paper:
# Covid-19 affects taste independently of smell: results from a combined chemosensory home test and online survey from a global cohort (N=10,953).
# Covid-19 affects taste independent of taste-smell confusions: results from a combined chemosensory home test and online survey from a large global cohort.
# found similar paper:
# Predicting SARS-CoV-2 infection among hemodialysis patients using multimodal data.
# Predicting SARS-CoV-2 infection among hemodialysis patients using deep neural network methods.
# found similar paper:
# Self-assembly of DNA nanostructures in different cations.
# Self-Assembly of DNA Nanostructures in Different Cations.
# found similar paper:
# Rolosense: Mechanical detection of SARS-CoV-2 using a DNA-based motor.
# Rolosense: Mechanical Detection of SARS-CoV-2 Using a DNA-Based Motor.
# found similar paper:
# Outbreak.info Research Library: A standardized, searchable platform to discover and explore COVID-19 resources.
# Outbreak.info Research Library: a standardized, searchable platform to discover and explore COVID-19 resources.
# found similar paper:
# Development of a Novel Human CD147 Knock-in NSG Mouse Model to Test SARS-CoV-2 Viral Infection.
# Development of a novel human CD147 knock-in NSG mouse model to test SARS-CoV-2 viral infection.
# found similar paper:
# Rhoptry secretion system structure and priming in Plasmodium falciparum revealed using in situ cryo-electron tomography.
# Rhoptry secretion system structure and priming in Plasmodium falciparum revealed using in situ cryo-electron tomography.
# found similar paper:
# IL-1 receptor antagonist, MIS-C, and the peculiar autoimmunity of SARS-CoV-2.
# IL-1 receptor antagonist, MIS-C, and the peculiar autoimmunity of SARS-CoV-2.
# found similar paper:
# American College of Rheumatology Clinical Guidance for Multisystem Inflammatory Syndrome in Children Associated With SARS-CoV-2 and Hyperinflammation in Pediatric COVID-19: Version 3.
# American College of Rheumatology Clinical Guidance for Multisystem Inflammatory Syndrome in Children Associated With SARS-CoV-2 and Hyperinflammation in Pediatric COVID-19: Version 3.
# found similar paper:
# Enzymatic and structural characterization of HAD5, an essential phosphomannomutase of malaria-causing parasites.
# Enzymatic and structural characterization of HAD5, an essential phosphomannomutase of malaria-causing parasites.
# found similar paper:
# The Adaptive Olfactory Measure of Threshold (ArOMa-T): A rapid test of olfactory function.
# The Adaptive Olfactory Measure of Threshold (ArOMa-T): a rapid test of olfactory function.
# found similar paper:
# Genetic Diversity and Evolutionary Convergence of Cryptic SARS-CoV-2 Lineages Detected Via Wastewater Sequencing.
# Genetic diversity and evolutionary convergence of cryptic SARS- CoV-2 lineages detected via wastewater sequencing.
# found similar paper:
# SARS-CoV-2 and other respiratory pathogens are detected in continuous air samples from congregate settings.
# SARS-CoV-2 and other respiratory pathogens are detected in continuous air samples from congregate settings.
# found similar paper:
# Biomarkers Selection for Population Normalization in SARS-CoV-2 Wastewater-based Epidemiology.
# Biomarkers selection for population normalization in SARS-CoV-2 wastewater-based epidemiology.
# found similar paper:
# Proof-of-concept: SCENTinel 1.1 rapidly discriminates COVID-19 related olfactory disorders.
# Proof-of-concept: SCENTinel 1.1 rapidly discriminates COVID-19-related olfactory disorders.
# found similar paper:
# Taste loss as a distinct symptom of COVID-19: a systematic review and meta-analysis.
# Taste loss as a distinct symptom of COVID-19: a systematic review and meta-analysis.
# found similar paper:
# Publisher Correction: Tracking cryptic SARS-CoV-2 lineages detected in NYC wastewater.
# Tracking cryptic SARS-CoV-2 lineages detected in NYC wastewater.
# found similar paper:
# High-throughput sequencing of SARS-CoV-2 in wastewater provides insights into circulating variants.
# High-throughput sequencing of SARS-CoV-2 in wastewater provides insights into circulating variants.
# found similar paper:
# The Kinetics of COVID-19 Vaccine Response in a Community Vaccinated Population.
# The Kinetics of COVID-19 Vaccine Response in a Community-Vaccinated Population.
# found similar paper:
# Deletion of ER-retention Motif on SARS-CoV-2 Spike Protein Reduces Cell Hybrid During Cell-cell Fusion.
# Deletion of ER-retention motif on SARS-CoV-2 spike protein reduces cell hybrid during cell-cell fusion.
# found similar paper:
# Proteomic profiling of MIS-C patients indicates heterogeneity relating to interferon gamma dysregulation and vascular endothelial dysfunction.
# Proteomic profiling of MIS-C patients indicates heterogeneity relating to interferon gamma dysregulation and vascular endothelial dysfunction.
# found similar paper:
# Skewed Cytokine Responses Rather Than the Magnitude of the Cytokine Storm May Drive Cardiac Dysfunction in Multisystem Inflammatory Syndrome in Children.
# Skewed Cytokine Responses Rather Than the Magnitude of the Cytokine Storm May Drive Cardiac Dysfunction in Multisystem Inflammatory Syndrome in Children.
# found similar paper:
# Proteomic Profiling of MIS-C Patients Reveals Heterogeneity Relating to Interferon Gamma Dysregulation and Vascular Endothelial Dysfunction.
# Proteomic profiling of MIS-C patients indicates heterogeneity relating to interferon gamma dysregulation and vascular endothelial dysfunction.
# found similar paper:
# Proteomic Profiling of MIS-C Patients Reveals Heterogeneity Relating to Interferon Gamma Dysregulation and Vascular Endothelial Dysfunction.
# Proteomic profiling of MIS-C patients indicates heterogeneity relating to interferon gamma dysregulation and vascular endothelial dysfunction.
# found similar paper:
# Cutaneous Findings in SARS-CoV-2-Associated Multisystem Inflammatory Disease in Children.
# Cutaneous Findings in SARS-CoV-2-Associated Multisystem Inflammatory Disease in Children.
# found similar paper:
# Deep immune profiling of MIS-C demonstrates marked but transient immune activation compared to adult and pediatric COVID-19.
# Deep immune profiling of MIS-C demonstrates marked but transient immune activation compared to adult and pediatric COVID-19.
# found similar paper:
# American College of Rheumatology Clinical Guidance for Multisystem Inflammatory Syndrome in Children Associated With SARS-CoV-2 and Hyperinflammation in Pediatric COVID-19: Version 2.
# American College of Rheumatology Clinical Guidance for Multisystem Inflammatory Syndrome in Children Associated With SARS-CoV-2 and Hyperinflammation in Pediatric COVID-19: Version 3.
# found similar paper:
# American College of Rheumatology Clinical Guidance for Multisystem Inflammatory Syndrome in Children Associated With SARS-CoV-2 and Hyperinflammation in Pediatric COVID-19: Version 2.
# American College of Rheumatology Clinical Guidance for Multisystem Inflammatory Syndrome in Children Associated With SARS-CoV-2 and Hyperinflammation in Pediatric COVID-19: Version 3.
# found similar paper:
# Severe Acute Respiratory Syndrome-Coronavirus-2 (SARS-CoV-2) Antibody Responses in Children With Multisystem Inflammatory Syndrome in Children (MIS-C) and Mild and Severe Coronavirus Disease 2019 (COVID-19).
# Severe Acute Respiratory Syndrome-Coronavirus-2 (SARS-CoV-2) Antibody Responses in Children With Multisystem Inflammatory Syndrome in Children (MIS-C) and Mild and Severe Coronavirus Disease 2019 (COVID-19).
# found similar paper:
# Emergence and Expansion of the SARS-CoV-2 Variant B.1.526 Identified in New York.
# Emergence and expansion of SARS-CoV-2 B.1.526 after identification in New York.
# found similar paper:
# Transmission of SARS-CoV-2 Considering Shared Chairs in Outpatient Dialysis: A Real-World Case-Control Study.
# Transmission of SARS-CoV-2 considering shared chairs in outpatient dialysis: a real-world case-control study.
# found similar paper:
# Taste loss as a distinct symptom of COVID-19: A systematic review and meta-analysis.
# Taste loss as a distinct symptom of COVID-19: a systematic review and meta-analysis.
# found similar paper:
# Concordance of Upper and Lower Respiratory Tract Samples for SARS-CoV-2 in Pediatric Patients: Research Letter.
# Concordance of Upper and Lower Respiratory Tract Samples for SARS-CoV-2 in Pediatric Patients: Research Letter.
# found similar paper:
# Robust estimation of SARS-CoV-2 epidemic in US counties.
# Robust estimation of SARS-CoV-2 epidemic in US counties.
# found similar paper:
# Evidence of thrombotic microangiopathy in children with SARS-CoV-2 across the spectrum of clinical presentations.
# Evidence of thrombotic microangiopathy in children with SARS-CoV-2 across the spectrum of clinical presentations.
# found similar paper:
# Distinguishing Multisystem Inflammatory Syndrome in Children From Kawasaki Disease and Benign Inflammatory Illnesses in the SARS-CoV-2 Pandemic.
# Distinguishing Multisystem Inflammatory Syndrome in Children From Kawasaki Disease and Benign Inflammatory Illnesses in the SARS-CoV-2 Pandemic.
# found similar paper:
# Multidisciplinary Guidance Regarding the Use of Immunomodulatory Therapies for Acute Coronavirus Disease 2019 in Pediatric Patients.
# Multidisciplinary Guidance Regarding the Use of Immunomodulatory Therapies for Acute Coronavirus Disease 2019 in Pediatric Patients.
# found similar paper:
# An 81-Nucleotide Deletion in SARS-CoV-2 ORF7a Identified from Sentinel Surveillance in Arizona (January to March 2020).
# An 81 base-pair deletion in SARS-CoV-2 ORF7a identified from sentinel surveillance in Arizona (Jan-Mar 2020).
# found similar paper:
# Network Medicine Framework for Identifying Drug Repurposing Opportunities for COVID-19.
# Network medicine framework for identifying drug-repurposing opportunities for COVID-19.
# Number of raw publications after eliminating duplicate titles: 692

# %%
publications[publications["title"].str.contains("Correction")]
# Out:
# Empty DataFrame
# Columns: [pm_id, pmc_id, doi, title, abstract, keywords, authors, journal, year, publication_date, article_type, project_serial_num, Unnamed: 13, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, award_type, supplement, research_initiative, sub_project]
# Index: []

# %%
publications.query("pm_id == '38859985'")
# Out:
#         pm_id       pmc_id                     doi  \
# 115  38859985  PMC11163376  doi:10.1093/ve/veae034
#
#                                                  title  \
# 115  Within-host influenza viral diversity in the p...
#
#                                               abstract  \
# 115  Seasonal influenza virus predominantly evolves...
#
#                                               keywords  \
# 115  antigenic drift|influenza|next-generation sequ...
#
#                                                authors          journal  year  \
# 115  Sobel Leonard, Ashley|Mendoza, Lydia|McFarland...  Virus evolution  2024
#
#     publication_date     article_type project_serial_num Unnamed: 13  \
# 115       2024-01-01  Journal Article           HD105594
#
#     Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 award_type  supplement  \
# 115                                                        R61       False
#
#     research_initiative   sub_project
# 115            RADx-rad  PreVAIL kIds

# %%
publications[publications["pm_id"].isin(["32511591", "32357959"])]
# Out:
#         pm_id      pmc_id                              doi  \
# 611  32511591  PMC7276018  doi:10.1101/2020.04.17.20069641
#
#                                                  title abstract keywords  \
# 611  An 81 base-pair deletion in SARS-CoV-2 ORF7a i...
#
#                                                authors  \
# 611  Holland, LaRinda A|Kaelin, Emily A|Maqsood, Ra...
#
#                                                journal  year publication_date  \
# 611  medRxiv : the preprint server for health sciences  2020       2020-04-22
#
#                  article_type project_serial_num Unnamed: 13 Unnamed: 14  \
# 611  Journal Article|Preprint           LM013129
#
#     Unnamed: 15 Unnamed: 16 Unnamed: 17 award_type  supplement  \
# 611                                            U01        True
#
#     research_initiative sub_project
# 611            RADx-rad  Wastewater

# %%
publications.sort_values(by="title", inplace=True)
publications
# Out:
#         pm_id       pmc_id                                        doi  \
# 408  36275710   PMC9581391             doi:10.3389/fimmu.2022.1008390
# 140  38214887  PMC10947818                 doi:10.1002/anie.202316851
# 599  34654633                          doi:10.1053/j.jvca.2021.09.032
# 15   39793745                        doi:10.1016/j.actbio.2025.01.006
# 163  38516674  PMC10956508                      doi:10.36922/ijb.0118
# 187  37098909  PMC10190252                   doi:10.1128/mra.00069-23
# 321  34936725   PMC8854333                 doi:10.1002/anie.202112995
# 145  38507737  PMC11219269          doi:10.1158/1535-7163.MCT-23-0540
# 322  34889013   PMC8854376                 doi:10.1002/anie.202113617
# 683  27729363   PMC5079441         doi:10.1161/CIRCIMAGING.116.005091
# 651       False            RADx-rad       Novel Biosensing and VOC
# 622       False            RADx-rad       Novel Biosensing and VOC
# 553       False            RADx-rad       Novel Biosensing and VOC
# 557       False            RADx-rad       Novel Biosensing and VOC
# 563       False            RADx-rad       Novel Biosensing and VOC
# 668        True            RADx-rad           Chemosensory Testing
# 363       False            RADx-rad                   PreVAIL kIds
# 461       False            RADx-rad                   PreVAIL kIds
# 11        False            RADx-rad                   PreVAIL kIds
# 66         True            RADx-rad                     Wastewater
# 240       False            RADx-rad                          SCENT
# 445       False            RADx-rad                     Wastewater
# 3         False            RADx-rad                     Wastewater
# 294       False            RADx-rad                   PreVAIL kIds
# 639       False            RADx-rad           Chemosensory Testing
# 39        False            RADx-rad  Automatic Detection & Tracing
# 524       False            RADx-rad       Novel Biosensing and VOC
# 158       False            RADx-rad       Data Coordinating Center
# 400       False            RADx-rad                   PreVAIL kIds
# 519       False            RADx-rad                          SCENT
# 560       False            RADx-rad       Novel Biosensing and VOC
# 447       False            RADx-rad       Novel Biosensing and VOC
# 385       False            RADx-rad  Automatic Detection & Tracing
# 88        False            RADx-rad                   PreVAIL kIds
# 367       False            RADx-rad                          SCENT
# 680       False            RADx-rad       Novel Biosensing and VOC
# 242       False            RADx-rad                          SCENT
# 621       False            RADx-rad       Novel Biosensing and VOC
# 508        True            RADx-rad                     Wastewater
# 571       False            RADx-rad           Chemosensory Testing
# 428       False            RADx-rad                     Wastewater
# 93        False            RADx-rad       Novel Biosensing and VOC
# 175       False            RADx-rad        Multimodal Surveillance
# 173       False            RADx-rad        Multimodal Surveillance
# 319       False            RADx-rad        Multimodal Surveillance
# 320       False            RADx-rad        Multimodal Surveillance
# 499       False            RADx-rad                     Wastewater
# 312       False            RADx-rad        Multimodal Surveillance
# 134        True            RADx-rad       Novel Biosensing and VOC
# 40        False            RADx-rad                        Exosome
# 623       False            RADx-rad       Novel Biosensing and VOC
# 647       False            RADx-rad       Novel Biosensing and VOC
# 252       False            RADx-rad       Novel Biosensing and VOC
# 238       False            RADx-rad                   PreVAIL kIds
# 146        True            RADx-rad       Novel Biosensing and VOC
# 466        True            RADx-rad       Novel Biosensing and VOC
# 143       False            RADx-rad                   PreVAIL kIds
# 107       False            RADx-rad                   PreVAIL kIds
# 133        True            RADx-rad       Novel Biosensing and VOC
# 532       False            RADx-rad                   PreVAIL kIds
# 292       False            RADx-rad                          SCENT
# 243       False            RADx-rad                          SCENT
# 460       False            RADx-rad                          SCENT
# 210       False            RADx-rad                          SCENT
# 609       False            RADx-rad        Multimodal Surveillance
# 654       False            RADx-rad       Novel Biosensing and VOC
# 185       False            RADx-rad                     Wastewater
# 539       False            RADx-rad                          SCENT
# 121       False            RADx-rad        Multimodal Surveillance
# 403       False            RADx-rad                          SCENT
# 42         True            RADx-rad       Novel Biosensing and VOC
# 573       False            RADx-rad        Multimodal Surveillance
# 488       False            RADx-rad       Data Coordinating Center
# 98        False            RADx-rad       Novel Biosensing and VOC
# 592       False            RADx-rad  Automatic Detection & Tracing
# 200       False            RADx-rad                   PreVAIL kIds
# 625       False            RADx-rad       Novel Biosensing and VOC
# 283       False            RADx-rad           Chemosensory Testing
# 37         True            RADx-rad       Novel Biosensing and VOC
# 318       False            RADx-rad        Multimodal Surveillance
# 174       False            RADx-rad        Multimodal Surveillance
# 564       False            RADx-rad                   PreVAIL kIds
# 465        True            RADx-rad       Novel Biosensing and VOC
# 555       False            RADx-rad       Novel Biosensing and VOC
# 582        True            RADx-rad       Novel Biosensing and VOC
# 250       False            RADx-rad       Novel Biosensing and VOC
# 679       False            RADx-rad       Novel Biosensing and VOC
# 415       False            RADx-rad       Novel Biosensing and VOC
# 257       False            RADx-rad       Novel Biosensing and VOC
# 204       False            RADx-rad                   PreVAIL kIds
# 449        True            RADx-rad       Novel Biosensing and VOC
# 584        True            RADx-rad       Novel Biosensing and VOC
# 49        False            RADx-rad                     Wastewater
# 160       False            RADx-rad       Data Coordinating Center
# 284       False            RADx-rad  Automatic Detection & Tracing
# 43         True            RADx-rad       Novel Biosensing and VOC
# 6         False            RADx-rad                        Exosome
# 223       False            RADx-rad  Automatic Detection & Tracing
# 629       False            RADx-rad       Novel Biosensing and VOC
# 97        False            RADx-rad       Novel Biosensing and VOC
# 492       False            RADx-rad        Multimodal Surveillance
# 313       False            RADx-rad        Multimodal Surveillance
# 285       False            RADx-rad  Automatic Detection & Tracing
# 435        True            RADx-rad           Chemosensory Testing
# 581        True            RADx-rad       Novel Biosensing and VOC
# 324       False            RADx-rad                     Wastewater
# 646       False            RADx-rad       Novel Biosensing and VOC
# 482        True            RADx-rad       Novel Biosensing and VOC
# 198       False            RADx-rad  Automatic Detection & Tracing
# 549       False            RADx-rad       Novel Biosensing and VOC
# 588        True            RADx-rad       Novel Biosensing and VOC
# 225       False            RADx-rad  Automatic Detection & Tracing
# 424       False            RADx-rad                   PreVAIL kIds
# 351       False            RADx-rad                        Exosome
# 548       False            RADx-rad       Novel Biosensing and VOC
# 690       False            RADx-rad       Novel Biosensing and VOC
# 575       False            RADx-rad        Multimodal Surveillance
# 642       False            RADx-rad       Novel Biosensing and VOC
# 595       False            RADx-rad                        Exosome
# 139       False            RADx-rad  Automatic Detection & Tracing
# 689       False            RADx-rad       Novel Biosensing and VOC
# 53        False            RADx-rad       Data Coordinating Center
# 547       False            RADx-rad       Novel Biosensing and VOC
# 576       False            RADx-rad        Multimodal Surveillance
# 305       False            RADx-rad                   PreVAIL kIds
# 410       False            RADx-rad       Novel Biosensing and VOC
# 442       False            RADx-rad                     Wastewater
# 402       False            RADx-rad                   PreVAIL kIds
# 437       False            RADx-rad        Multimodal Surveillance
# 401       False            RADx-rad                   PreVAIL kIds
# 590       False            RADx-rad           Chemosensory Testing
# 307       False            RADx-rad       Data Coordinating Center
# 371       False            RADx-rad  Automatic Detection & Tracing
# 122       False            RADx-rad        Multimodal Surveillance
# 55        False            RADx-rad       Data Coordinating Center
# 675       False            RADx-rad       Novel Biosensing and VOC
# 346       False            RADx-rad                        Exosome
# 201       False            RADx-rad                   PreVAIL kIds
# 219       False            RADx-rad                   PreVAIL kIds
# 577       False            RADx-rad        Multimodal Surveillance
# 81        False            RADx-rad                   PreVAIL kIds
# 311       False            RADx-rad       Novel Biosensing and VOC
# 123       False            RADx-rad        Multimodal Surveillance
# 545       False            RADx-rad       Novel Biosensing and VOC
# 271       False            RADx-rad       Novel Biosensing and VOC
# 222       False            RADx-rad  Automatic Detection & Tracing
# 33         True            RADx-rad       Novel Biosensing and VOC
# 25        False            RADx-rad       Novel Biosensing and VOC
# 153       False            RADx-rad       Data Coordinating Center
# 288       False            RADx-rad                     Wastewater
# 568       False            RADx-rad                   PreVAIL kIds
# 587        True            RADx-rad       Novel Biosensing and VOC
# 150       False            RADx-rad                        Exosome
# 504       False            RADx-rad                     Wastewater
# 71        False            RADx-rad                     Wastewater
# 308       False            RADx-rad       Data Coordinating Center
# 565       False            RADx-rad                   PreVAIL kIds
# 397       False            RADx-rad                   PreVAIL kIds
# 407       False            RADx-rad       Novel Biosensing and VOC
# 315       False            RADx-rad        Multimodal Surveillance
# 41        False            RADx-rad                        Exosome
# 452        True            RADx-rad       Novel Biosensing and VOC
# 304        True            RADx-rad       Novel Biosensing and VOC
# 193       False            RADx-rad                     Wastewater
# 246       False            RADx-rad                          SCENT
# 235       False            RADx-rad                   PreVAIL kIds
# 179       False            RADx-rad                     Wastewater
# 205       False            RADx-rad                   PreVAIL kIds
# 325       False            RADx-rad                     Wastewater
# 191        True            RADx-rad                     Wastewater
# 381       False            RADx-rad  Automatic Detection & Tracing
# 333       False            RADx-rad                     Wastewater
# 650       False            RADx-rad       Novel Biosensing and VOC
# 360       False            RADx-rad                   PreVAIL kIds
# 515       False            RADx-rad                   PreVAIL kIds
# 627       False            RADx-rad       Novel Biosensing and VOC
# 686       False            RADx-rad       Novel Biosensing and VOC
# 281       False            RADx-rad           Chemosensory Testing
# 149       False            RADx-rad           Chemosensory Testing
# 604       False            RADx-rad        Multimodal Surveillance
# 264       False            RADx-rad        Multimodal Surveillance
# 47        False            RADx-rad           Chemosensory Testing
# 453       False            RADx-rad           Chemosensory Testing
# 432       False            RADx-rad           Chemosensory Testing
# 31        False            RADx-rad                   PreVAIL kIds
# 448        True            RADx-rad       Novel Biosensing and VOC
# 353       False            RADx-rad                        Exosome
# 498       False            RADx-rad                     Wastewater
# 628       False            RADx-rad       Novel Biosensing and VOC
# 583        True            RADx-rad       Novel Biosensing and VOC
# 638       False            RADx-rad           Chemosensory Testing
# 591       False            RADx-rad           Chemosensory Testing
# 116       False            RADx-rad                   PreVAIL kIds
# 265       False            RADx-rad        Multimodal Surveillance
# 486       False            RADx-rad                     Wastewater
# 248       False            RADx-rad       Novel Biosensing and VOC
# 274        True            RADx-rad       Novel Biosensing and VOC
# 62        False            RADx-rad                     Wastewater
# 125       False            RADx-rad                     Wastewater
# 444       False            RADx-rad                     Wastewater
# 458       False            RADx-rad                     Wastewater
# 439       False            RADx-rad        Multimodal Surveillance
# 262       False            RADx-rad           Chemosensory Testing
# 572       False            RADx-rad        Multimodal Surveillance
# 278        True            RADx-rad       Novel Biosensing and VOC
Research Support, N.I.H., Extramural|Research Support, Non-U.S. Gov't                                                            1
# Journal Article|Systematic Review                                                                                                                                        1
# Clinical Trial|Journal Article|Research Support, N.I.H., Extramural                                                                                                      1
# Journal Article|Validation Study                                                                                                                                         1
# Editorial                                                                                                                                                                1
# Journal Article|Observational Study|Research Support, N.I.H., Extramural                                                                                                 1
# Clinical Study|Journal Article|Research Support, N.I.H., Extramural|Research Support, Non-U.S. Gov't                                                                     1
# Clinical Trial, Phase III|Journal Article|Randomized Controlled Trial|Research Support, N.I.H., Extramural|Validation Study                                              1
# Comparative Study|Journal Article|Multicenter Study|Research Support, N.I.H., Extramural                                                                                 1
# Journal Article|Research Support, N.I.H., Extramural|Research Support, N.I.H., Intramural|Research Support, Non-U.S. Gov't|Review                                        1
# Letter|Research Support, N.I.H., Extramural|Research Support, Non-U.S. Gov't|Research Support, U.S. Gov't, P.H.S.                                                        1
# Journal Article|Research Support, N.I.H., Extramural|Research Support, U.S. Gov't, Non-P.H.S.|Review                                                                     1
# Journal Article|Research Support, U.S. Gov't, P.H.S.                                                                                                                     1
# Case Reports|Journal Article|Research Support, N.I.H., Extramural                                                                                                        1
# Congress|Editorial|Research Support, N.I.H., Extramural|Research Support, Non-U.S. Gov't|Research Support, U.S. Gov't, Non-P.H.S.                                        1
# Proceedings                                                                                                                                                              1
# Journal Article|Research Support, U.S. Gov't, P.H.S.|Review                                                                                                              1
# Historical Article|Journal Article|Research Support, N.I.H., Extramural|Research Support, U.S. Gov't, Non-P.H.S.                                                         1
# Name: count, dtype: int64

# %%
print(f"Raw number of publications: {publications.shape[0]}")
# Out:
# Raw number of publications: 692

# %%
publications.query("project_serial_num == 'AA029316'")
# Out:
#         pm_id       pmc_id                               doi  \
# 372  35532905   PMC9112978  doi:10.1021/acs.analchem.2c00554
# 216  37206388  PMC10189874            doi:10.1039/d3sc00439b
# 520  34328683   PMC8426805        doi:10.1002/anie.202107730
# 371  35972202   PMC9397568  doi:10.1021/acs.analchem.2c01993
#
#                                                  title  \
# 372  Aptamer Sandwich Lateral Flow Assay (AptaFlow)...
# 216  Aptamers 101: aptamer discovery and <i>in vitr...
# 520  Discovery and Characterization of Spike N-Term...
# 371  SCORe: SARS-CoV-2 Omicron Variant RBD-Binding ...
#
#                                               abstract  \
# 372  The COVID-19 pandemic is among the greatest he...
# 216  Aptamers are single-stranded nucleic acids tha...
# 520  The coronavirus disease 2019 (COVID-19) pandem...
# 371  During the COVID-19 (coronavirus disease 2019)...
#
#                                               keywords  \
# 372  Antibodies, Viral|Aptamers, Nucleotide|COVID-1...
# 216
# 520  Aptamers, Nucleotide|COVID-19|Enzyme-Linked Im...
# 371  Angiotensin-Converting Enzyme 2|Antibodies, Vi...
#
#                                                authors  \
# 372  Yang, Lucy F|Kacherovsky, Nataly|Panpradist, N...
# 216  Yang, Lucy F|Ling, Melissa|Kacherovsky, Nataly...
# 520  Kacherovsky, Nataly|Yang, Lucy F|Dang, Ha V|Ch...
# 371  Yang, Lucy F|Kacherovsky, Nataly|Liang, Joey|S...
#
#                                               journal  year publication_date  \
# 372                              Analytical chemistry  2022       2022-05-24
# 216                                  Chemical science  2023       2023-05-17
# 520  Angewandte Chemie (International ed. in English)  2021       2021-09-20
# 371                              Analytical chemistry  2022       2022-09-20
#
#                                           article_type project_serial_num  \
# 372  Journal Article|Research Support, N.I.H., Extr...           AA029316
# 216                             Journal Article|Review           AA029316
# 520  Journal Article|Research Support, N.I.H., Extr...           AA029316
# 371  Journal Article|Research Support, N.I.H., Extr...           AA029316
#
#     Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 award_type  \
# 372                                                                    U01
# 216                                                                    U01
# 520                                                                    U01
# 371                                                                    U01
#
#      supplement research_initiative                    sub_project
# 372       False            RADx-rad  Automatic Detection & Tracing
# 216       False            RADx-rad  Automatic Detection & Tracing
# 520       False            RADx-rad  Automatic Detection & Tracing
# 371       False            RADx-rad  Automatic Detection & Tracing

# %%
publications[publications["pm_id"].isin({"34328683", "34607084", "35200361", "36292760", "37160974", "37851606", "38214887"})]
# Out:
#         pm_id       pmc_id                               doi  \
# 140  38214887  PMC10947818        doi:10.1002/anie.202316851
# 249  37851606  PMC10584126  doi:10.1371/journal.pone.0286988
# 358  36292760   PMC9602126         doi:10.3390/genes13101874
# 473  35200361   PMC8869940          doi:10.3390/bios12020101
# 489  34328683   PMC8426805        doi:10.1002/anie.202107730
# 520  34328683   PMC8426805        doi:10.1002/anie.202107730
# 505  34607084   PMC8464352  doi:10.1016/j.watres.2021.117710
# 183  37160974  PMC10169181    doi:10.1038/s41467-023-38400-0
#
#                                                  title  \
# 140  "Turbo-Charged" DNA Motors with Optimized Sequ...
# 249  A spatially uniform illumination source for wi...
# 358  Confounding Factors Impacting microRNA Express...
# 473       Context-Aware Diagnostic Specificity (CADS).
# 489  Discovery and Characterization of Spike N-Term...
# 520  Discovery and Characterization of Spike N-Term...
# 505  High-throughput sequencing of SARS-CoV-2 in wa...
# 183  Highly host-linked viromes in the built enviro...
#
#                                               abstract  \
# 140  DNA motors that consume chemical energy to gen...
# 249  Illumination uniformity is a critical paramete...
# 358  There is growing interest in saliva microRNAs ...
# 473  Rapid detection of proteins is critical in a v...
# 489  The coronavirus disease 2019 (COVID-19) pandem...
# 520  The coronavirus disease 2019 (COVID-19) pandem...
# 505  Severe acute respiratory syndrome coronavirus ...
# 183  Viruses in built environments (BEs) raise publ...
#
#                                               keywords  \
# 140  DNA|DNA motors|DNA nanotechnology|Molecular Mo...
# 249                Lighting|Microscopy|Optical Devices
# 358  Biomarkers|Humans|MicroRNAs|Reproducibility of...
# 473  Humans|Models, Statistical|Proteins|Sensitivit...
# 489  Aptamers, Nucleotide|COVID-19|Enzyme-Linked Im...
# 520  Aptamers, Nucleotide|COVID-19|Enzyme-Linked Im...
# 505  COVID-19|High-Throughput Nucleotide Sequencing...
# 183  Alkanesulfonic Acids|Built Environment|Microbi...
#
#                                                authors  \
# 140  Zhang, Luona|Piranej, Selma|Namazi, Arshiya|Na...
# 249             Çelebi, İris|Aslan, Mete|Ünlü, M Selim
# 358  Sullivan, Rhea|Montgomery, Austin|Scipioni, An...
# 473  McLamore, Eric S|Moreira, Geisianny|Vanegas, D...
# 489  Kacherovsky, Nataly|Yang, Lucy F|Dang, Ha V|Ch...
# 520  Kacherovsky, Nataly|Yang, Lucy F|Dang, Ha V|Ch...
# 505  Fontenele, Rafaela S|Kraberger, Simona|Hadfiel...
# 183  Du, Shicong|Tong, Xinzhao|Lai, Alvin C K|Chan,...
#
#                                               journal  year publication_date  \
# 140  Angewandte Chemie (International ed. in English)  2024       2024-03-22
# 249                                          PloS one  2023       2023-01-01
# 358                                             Genes  2022       2022-10-16
# 473                                        Biosensors  2022       2022-02-07
# 489  Angewandte Chemie (International ed. in English)  2021       2021-09-20
# 520  Angewandte Chemie (International ed. in English)  2021       2021-09-20
# 505                                    Water research  2021       2021-10-15
# 183                             Nature communications  2023       2023-05-09
#
#                                           article_type project_serial_num  \
# 140  Journal Article|Research Support, N.I.H., Extr...           AA029345
# 249                                    Journal Article           HL119145
# 358  Journal Article|Research Support, N.I.H., Extr...           HD105610
# 473                                          Editorial           AA029328
# 489  Journal Article|Research Support, N.I.H., Extr...           LM013755
# 520  Journal Article|Research Support, N.I.H., Extr...           AA029316
# 505                                    Journal Article           LM013129
# 183  Journal Article|Research Support, N.I.H., Extr...           DA053941
#
#     Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 award_type  \
# 140                                                                    U01
# 249                                                                    U54
# 358                                                                    R61
# 473                                                                    U01
# 489                                                                    U24
# 520                                                                    U01
# 505                                                                    U01
# 183                                                                    U01
#
#      supplement research_initiative                    sub_project
# 140       False            RADx-rad  Automatic Detection & Tracing
# 249       False            RADx-rad       Novel Biosensing and VOC
# 358       False            RADx-rad                   PreVAIL kIds
# 473       False            RADx-rad  Automatic Detection & Tracing
# 489       False            RADx-rad       Data Coordinating Center
# 520       False            RADx-rad  Automatic Detection & Tracing
# 505        True            RADx-rad                     Wastewater
# 183       False            RADx-rad                     Wastewater

# %%
publications[publications["doi"].isin({"doi:10.1016/j.watres.2021.117710", "doi:10.3390/genes13101874"})]
# Out:
#         pm_id      pmc_id                               doi  \
# 358  36292760  PMC9602126         doi:10.3390/genes13101874
# 505  34607084  PMC8464352  doi:10.1016/j.watres.2021.117710
#
#                                                  title  \
# 358  Confounding Factors Impacting microRNA Express...
# 505  High-throughput sequencing of SARS-CoV-2 in wa...
#
#                                               abstract  \
# 358  There is growing interest in saliva microRNAs ...
# 505  Severe acute respiratory syndrome coronavirus ...
#
#                                               keywords  \
# 358  Biomarkers|Humans|MicroRNAs|Reproducibility of...
# 505  COVID-19|High-Throughput Nucleotide Sequencing...
#
#                                                authors         journal  year  \
# 358  Sullivan, Rhea|Montgomery, Austin|Scipioni, An...           Genes  2022
# 505  Fontenele, Rafaela S|Kraberger, Simona|Hadfiel...  Water research  2021
#
#     publication_date                                       article_type  \
# 358       2022-10-16  Journal Article|Research Support, N.I.H., Extr...
# 505       2021-10-15                                    Journal Article
#
#     project_serial_num Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 358           HD105610
# 505           LM013129
#
#     Unnamed: 17 award_type  supplement research_initiative   sub_project
# 358                    R61       False            RADx-rad  PreVAIL kIds
# 505                    U01        True            RADx-rad    Wastewater

# %%
# Remove duplicate DOI, project serial number pairs.
# The same publication may be related to multiple grants, 
# so we need make sure not to drop the project serial numbers.
publications.drop_duplicates(["doi", "project_serial_num"], inplace=True)
print(f"Raw number of de-duplicated publications: {publications.shape[0]}")
# Out:
# Raw number of de-duplicated publications: 689

# %%
publications[publications["doi"].isin({"doi:10.1016/j.watres.2021.117710", "doi:10.3390/genes13101874"})]
# Out:
#         pm_id      pmc_id                               doi  \
# 358  36292760  PMC9602126         doi:10.3390/genes13101874
# 505  34607084  PMC8464352  doi:10.1016/j.watres.2021.117710
#
#                                                  title  \
# 358  Confounding Factors Impacting microRNA Express...
# 505  High-throughput sequencing of SARS-CoV-2 in wa...
#
#                                               abstract  \
# 358  There is growing interest in saliva microRNAs ...
# 505  Severe acute respiratory syndrome coronavirus ...
#
#                                               keywords  \
# 358  Biomarkers|Humans|MicroRNAs|Reproducibility of...
# 505  COVID-19|High-Throughput Nucleotide Sequencing...
#
#                                                authors         journal  year  \
# 358  Sullivan, Rhea|Montgomery, Austin|Scipioni, An...           Genes  2022
# 505  Fontenele, Rafaela S|Kraberger, Simona|Hadfiel...  Water research  2021
#
#     publication_date                                       article_type  \
# 358       2022-10-16  Journal Article|Research Support, N.I.H., Extr...
# 505       2021-10-15                                    Journal Article
#
#     project_serial_num Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 358           HD105610
# 505           LM013129
#
#     Unnamed: 17 award_type  supplement research_initiative   sub_project
# 358                    R61       False            RADx-rad  PreVAIL kIds
# 505                    U01        True            RADx-rad    Wastewater

# %%
publications[publications["title"].str.startswith("High-throughput sequencing of SARS-CoV-2")]
# Out:
#         pm_id      pmc_id                               doi  \
# 505  34607084  PMC8464352  doi:10.1016/j.watres.2021.117710
#
#                                                  title  \
# 505  High-throughput sequencing of SARS-CoV-2 in wa...
#
#                                               abstract  \
# 505  Severe acute respiratory syndrome coronavirus ...
#
#                                               keywords  \
# 505  COVID-19|High-Throughput Nucleotide Sequencing...
#
#                                                authors         journal  year  \
# 505  Fontenele, Rafaela S|Kraberger, Simona|Hadfiel...  Water research  2021
#
#     publication_date     article_type project_serial_num Unnamed: 13  \
# 505       2021-10-15  Journal Article           LM013129
#
#     Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 award_type  supplement  \
# 505                                                        U01        True
#
#     research_initiative sub_project
# 505            RADx-rad  Wastewater

# %%
# Drop rows with duplicate PMC Ids (keep the publications with a later publication date)
publications.sort_values(by="year", ascending=False, inplace=True)

# %%
# Drop rows with duplicate title and project serial number
publications.drop_duplicates(["title", "project_serial_num"], inplace=True)

# %%
print(f"Number of de-duplicated publications with DOI: {publications.shape[0]}")
# Out:
# Number of de-duplicated publications with DOI: 689

# %%
publications.to_csv(os.path.join(DERIVED_DATA_PATH, "publications_pubmed_raw.csv"), index=False)

# %%
publications[publications["pm_id"].isin({"34328683", "34607084", "35200361", "36292760", "37160974", "37851606", "38214887"})]
# Out:
#         pm_id       pmc_id                               doi  \
# 140  38214887  PMC10947818        doi:10.1002/anie.202316851
# 183  37160974  PMC10169181    doi:10.1038/s41467-023-38400-0
# 249  37851606  PMC10584126  doi:10.1371/journal.pone.0286988
# 473  35200361   PMC8869940          doi:10.3390/bios12020101
# 358  36292760   PMC9602126         doi:10.3390/genes13101874
# 505  34607084   PMC8464352  doi:10.1016/j.watres.2021.117710
# 520  34328683   PMC8426805        doi:10.1002/anie.202107730
# 489  34328683   PMC8426805        doi:10.1002/anie.202107730
#
#                                                  title  \
# 140  "Turbo-Charged" DNA Motors with Optimized Sequ...
# 183  Highly host-linked viromes in the built enviro...
# 249  A spatially uniform illumination source for wi...
# 473       Context-Aware Diagnostic Specificity (CADS).
# 358  Confounding Factors Impacting microRNA Express...
# 505  High-throughput sequencing of SARS-CoV-2 in wa...
# 520  Discovery and Characterization of Spike N-Term...
# 489  Discovery and Characterization of Spike N-Term...
#
#                                               abstract  \
# 140  DNA motors that consume chemical energy to gen...
# 183  Viruses in built environments (BEs) raise publ...
# 249  Illumination uniformity is a critical paramete...
# 473  Rapid detection of proteins is critical in a v...
# 358  There is growing interest in saliva microRNAs ...
# 505  Severe acute respiratory syndrome coronavirus ...
# 520  The coronavirus disease 2019 (COVID-19) pandem...
# 489  The coronavirus disease 2019 (COVID-19) pandem...
#
#                                               keywords  \
# 140  DNA|DNA motors|DNA nanotechnology|Molecular Mo...
# 183  Alkanesulfonic Acids|Built Environment|Microbi...
# 249                Lighting|Microscopy|Optical Devices
# 473  Humans|Models, Statistical|Proteins|Sensitivit...
# 358  Biomarkers|Humans|MicroRNAs|Reproducibility of...
# 505  COVID-19|High-Throughput Nucleotide Sequencing...
# 520  Aptamers, Nucleotide|COVID-19|Enzyme-Linked Im...
# 489  Aptamers, Nucleotide|COVID-19|Enzyme-Linked Im...
#
#                                                authors  \
# 140  Zhang, Luona|Piranej, Selma|Namazi, Arshiya|Na...
# 183  Du, Shicong|Tong, Xinzhao|Lai, Alvin C K|Chan,...
# 249             Çelebi, İris|Aslan, Mete|Ünlü, M Selim
# 473  McLamore, Eric S|Moreira, Geisianny|Vanegas, D...
# 358  Sullivan, Rhea|Montgomery, Austin|Scipioni, An...
# 505  Fontenele, Rafaela S|Kraberger, Simona|Hadfiel...
# 520  Kacherovsky, Nataly|Yang, Lucy F|Dang, Ha V|Ch...
# 489  Kacherovsky, Nataly|Yang, Lucy F|Dang, Ha V|Ch...
#
#                                               journal  year publication_date  \
# 140  Angewandte Chemie (International ed. in English)  2024       2024-03-22
# 183                             Nature communications  2023       2023-05-09
# 249                                          PloS one  2023       2023-01-01
# 473                                        Biosensors  2022       2022-02-07
# 358                                             Genes  2022       2022-10-16
# 505                                    Water research  2021       2021-10-15
# 520  Angewandte Chemie (International ed. in English)  2021       2021-09-20
# 489  Angewandte Chemie (International ed. in English)  2021       2021-09-20
#
#                                           article_type project_serial_num  \
# 140  Journal Article|Research Support, N.I.H., Extr...           AA029345
# 183  Journal Article|Research Support, N.I.H., Extr...           DA053941
# 249                                    Journal Article           HL119145
# 473                                          Editorial           AA029328
# 358  Journal Article|Research Support, N.I.H., Extr...           HD105610
# 505                                    Journal Article           LM013129
# 520  Journal Article|Research Support, N.I.H., Extr...           AA029316
# 489  Journal Article|Research Support, N.I.H., Extr...           LM013755
#
#     Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 award_type  \
# 140                                                                    U01
# 183                                                                    U01
# 249                                                                    U54
# 473                                                                    U01
# 358                                                                    R61
# 505                                                                    U01
# 520                                                                    U01
# 489                                                                    U24
#
#      supplement research_initiative                    sub_project
# 140       False            RADx-rad  Automatic Detection & Tracing
# 183       False            RADx-rad                     Wastewater
# 249       False            RADx-rad       Novel Biosensing and VOC
# 473       False            RADx-rad  Automatic Detection & Tracing
# 358       False            RADx-rad                   PreVAIL kIds
# 505        True            RADx-rad                     Wastewater
# 520       False            RADx-rad  Automatic Detection & Tracing
# 489       False            RADx-rad       Data Coordinating Center

# %%
publications.tail()
# Out:
#         pm_id      pmc_id                               doi  \
# 686  27114509  PMC4868492       doi:10.1073/pnas.1525388113
# 689  26506125  PMC4674364  doi:10.1016/j.bbadis.2015.10.019
# 688  26968099  PMC5375104  doi:10.1016/j.bbalip.2016.03.007
# 691  26294733  PMC4666336  doi:10.3324/haematol.2015.132449
# 690  26149051  PMC5565795             doi:10.1111/jth.12942
#
#                                                  title  \
# 686  Targeted erythropoietin selectively stimulates...
# 689  S-adenosylhomocysteine induces inflammation th...
# 688    miRNA regulation of LDL-cholesterol metabolism.
# 691  Homozygous knockout of the piezo1 gene in the ...
# 690   Road blocks in making platelets for transfusion.
#
#                                               abstract  \
# 686  The design of cell-targeted protein therapeuti...
# 689  S-adenosylhomocysteine (SAH) can induce endoth...
# 688  In the past decade, microRNAs (miRNAs) have em...
# 691
# 690  The production of laboratory-generated human p...
#
#                                               keywords  \
# 686  Anemia|Animals|Drug Design|Erythropoiesis|Eryt...
# 689  Adhesion molecules|Cell Line|EZH2|Endothelial ...
# 688  Animals|Cardiovascular Diseases|Cholesterol, L...
# 691  Anemia|Animals|Gene Knockout Techniques|Homozy...
# 690  Bioreactors|Blood Platelets|Cell Culture Techn...
#
#                                                authors  \
# 686  Burrill, Devin R|Vernet, Andyna|Collins, James...
# 689  Barroso, Madalena|Kao, Derrick|Blom, Henk J|Ta...
# 688  Goedeke, Leigh|Wagschal, Alexandre|Fernández-H...
# 691  Shmukler, Boris E|Huston, Nicholas C|Thon, Jon...
# 690  Thon, J N|Medvetz, D A|Karlsson, S M|Italiano,...
#
#                                                journal  year publication_date  \
# 686  Proceedings of the National Academy of Science...  2016       2016-05-10
# 689                      Biochimica et biophysica acta  2016       2016-01-01
# 688                      Biochimica et biophysica acta  2016       2016-12-01
# 691                                      Haematologica  2015       2015-12-01
# 690        Journal of thrombosis and haemostasis : JTH  2015       2015-06-01
#
#                                           article_type project_serial_num  \
# 686  Journal Article|Research Support, N.I.H., Extr...           HL119145
# 689  Journal Article|Research Support, N.I.H., Extr...           HL119145
# 688  Journal Article|Research Support, N.I.H., Extr...           HL119145
# 691        Letter|Research Support, N.I.H., Extramural           HL119145
# 690  Journal Article|Research Support, N.I.H., Extr...           HL119145
#
#     Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 award_type  \
# 686                                                                    U54
# 689                                                                    U54
# 688                                                                    U54
# 691                                                                    U54
# 690                                                                    U54
#
#      supplement research_initiative               sub_project
# 686       False            RADx-rad  Novel Biosensing and VOC
# 689       False            RADx-rad  Novel Biosensing and VOC
# 688       False            RADx-rad  Novel Biosensing and VOC
# 691       False            RADx-rad  Novel Biosensing and VOC
# 690       False            RADx-rad  Novel Biosensing and VOC
